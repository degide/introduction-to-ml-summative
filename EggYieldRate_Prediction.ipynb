# %% [markdown]
# #### **Full Name**: HARERIMANA Egide
#
# #### **Intake:** September 2023
#
# #### **Cohort:** C1
#
# #### **Course:** Introduction to Machine Learning

# %% [markdown]
# # Predicting Smallholder Poultry Productivity: A Comparative Analysis of Machine Learning and Deep Learning for Egg Yield Rate
#
# ### Problem Statement
#
# The core objective of this notebook is to develop and compare predictive models for the Monthly Egg Yield Rate (`s11q2_4/s11q2_3`). By accurately forecasting the productivity of laying hens, this work aims to establish data-driven benchmarks, enabling extension services to identify optimal flock sizes, management practices, and intervention targets to enhance agricultural productivity and empower smallholder farmers in Rwanda.
#
# ### Data Source
#
# Source Name: Rwanda Agricultural Household Survey (AHS) 2024
#
# Specific File: AHS2024_Section11_2_EGG PRODUCTION.dta
#
# Type: Original Microdata (Non-Standard)
#
# Data Owner: National Institute of Statistics of Rwanda (NISR) - Ministry of Finance and Economic Planning
#
# URL: https://microdata.statistics.gov.rw/index.php/catalog/123/

# %% [markdown]
# # Essential Libraries and Imports

# %% [markdown]
# First and foremost, we start by installing and ensuring all essential libraries are available. These libraries are crucial for the next and the rest of the steps.

# %%
# %pip install -q pandas numpy matplotlib seaborn scikit-learn tensorflow

# %% [markdown]
# Next, let's import essential Python libraries.

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split, GridSearchCV, KFold
from sklearn.preprocessing import StandardScaler, OneHotEncoder, PolynomialFeatures
from sklearn.impute import SimpleImputer
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LinearRegression, Ridge, Lasso
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.metrics import r2_score, root_mean_squared_error

# TensorFlow imports
import tensorflow as tf
from tensorflow.keras import backend as K
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Dense, Dropout, Input
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping

tf.compat.v1.enable_eager_execution()
tf.compat.v1.enable_eager_execution()
tf.config.run_functions_eagerly(True)
tf.data.experimental.enable_debug_mode()

# Suppress TensorFlow warnings
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '1'

# %matplotlib inline

# %% [markdown]
# # Part 1: Data Preprocessing and Feature Engineering

# %% [markdown]
# ## 1.1 Data Loading
#
# This notebook initiates the data processing pipeline for the **Monthly Egg Yield Rate** prediction task. The core objective is to transform raw survey data from the Rwanda Agricultural Household Survey (AHS) 2024 into a structured format suitable for robust machine learning model training.
#
# The dataset, sourced from the National Institute of Statistics of Rwanda, is a real-world, non-standard microdata file (`.dta` format), which aligns with the assignment's requirement for using original data sources. We load the data using the `pandas` library.

# %%
# Set random seeds for reproducibility
np.random.seed(42)
tf.random.set_seed(42)

# %%
# Load the dataset
df = pd.read_stata('Microdata/AHS2024_Section11_2_EGG PRODUCTION.dta')

print(f"Initial DataFrame shape: {df.shape}")

df.info()
# Out:
# Initial DataFrame shape: (19077, 17)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19077 entries, 0 to 19076
# Data columns (total 17 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   hhid      19077 non-null  float32
#  1   clust     14223 non-null  float32
#  2   province  18916 non-null  category
#  3   district  18916 non-null  category
#  4   s11q2_1   19037 non-null  category
#  5   s11q2_2   11382 non-null  category
#  6   s11q2_0   11382 non-null  category
#  7   s11q2_3   3382 non-null   float64
#  8   s11q2_4   5468 non-null   float64
#  9   s11q2_5   5468 non-null   float64
#  10  s11q2_6   5468 non-null   float64
#  11  s11q2_7   3651 non-null   float64
#  12  s11q2_8   3382 non-null   float64
#  13  s11q2_9   5468 non-null   float64
#  14  weight    19077 non-null  float64
#  15  owner     19077 non-null  object
#  16  _merge    19077 non-null  category
# dtypes: category(6), float32(2), float64(8), object(1)
# memory usage: 1.6+ MB

# %% [markdown]
# ## 1.2 Data Cleaning: Filtering for Active Production Records
#
# ### Addressing Data Sparsity
# The raw dataset contains 19,077 entries, representing potential household-month observations. However, key production variables exhibit high sparsity (e.g., `s11q2_3` - Hens has only 3,382 non-null entries). This sparsity is typical in survey data, where null values often signify "no activity reported."
#
# For a meaningful productivity prediction (yield rate), we must filter the dataset to include only **active production months** where the inputs, outputs, and temporal context were recorded. This rigorous filtering process prevents the creation of undefined values (division by zero) and ensures the model is trained only on relevant data points.
#
# **Filtering Criteria:**
# 1.  **Output Recorded:** `s11q2_4` (Eggs Produced) is not missing.
# 2.  **Input Recorded:** `s11q2_3` (Number of Hens) is greater than 0.
# 3.  **Context Valid:** `s11q2_2` (Month) and geographic indicators are not missing.
#
# This approach significantly improves the quality of the regression task, focusing on the efficiency of active producers.

# %%
# Convert relevant columns to numeric type to handle potential mixed types from Stata
production_cols = ['s11q2_3', 's11q2_4', 's11q2_6', 's11q2_7']
for col in production_cols:
    df[col] = pd.to_numeric(df[col], errors='coerce')

# Strict filtering based on input (hens > 0), output (eggs reported), and essential categorical features
df_filtered = df.dropna(subset=['s11q2_4', 's11q2_2', 'province', 'district']).copy()
df_filtered = df_filtered[df_filtered['s11q2_3'] > 0].copy()

# Convert categorical columns to appropriate type.
categorical_cols = ['province', 'district', 's11q2_2']
df_filtered[categorical_cols] = df_filtered[categorical_cols].astype('category')

print(f"Final filtered shape: {df_filtered.shape}")
print(f"Number of active production records retained: {df_filtered.shape[0]}")
# Out:
# Final filtered shape: (3382, 17)
# Number of active production records retained: 3382

# %% [markdown]
# ## 1.3 Target Variable Creation ($\mathbf{Y}$) and Outlier Management
#
# ### Target Variable Engineering
# The central objective is to predict **Egg Yield Rate**. We engineer the target variable ($\mathbf{Y}$) by dividing the total number of eggs produced (`s11q2_4`) by the total number of laying hens (`s11q2_3`).
#
# $$\mathbf{Y}_{\text{Yield Rate}} = \frac{\text{s11q2\_4}}{\text{s11q2\_3}}$$
#
# ### Robust Outlier Handling
# The calculated yield rate can contain extreme outliers due to reporting errors (e.g., small flock, high egg count). Such outliers can heavily skew the cost function of both Ordinary Least Squares (used in Traditional ML models) and Deep Learning optimizers. To mitigate this risk, we cap the target variable at the **99th percentile**. This method is more robust than removing outliers entirely, as it retains data points while neutralizing their extreme influence.

# %%
# Calculate the Target Variable
df_filtered['YIELD_RATE'] = df_filtered['s11q2_4'] / df_filtered['s11q2_3']

# Determine the 99th percentile cap
cap_value = df_filtered['YIELD_RATE'].quantile(0.99)

# Apply capping
df_filtered['YIELD_RATE'] = np.where(
    df_filtered['YIELD_RATE'] > cap_value, 
    cap_value, 
    df_filtered['YIELD_RATE']
)

print(f"Target YIELD_RATE capped at the 99th percentile: {cap_value:.2f}")
print("YIELD_RATE Descriptive Statistics after Capping:")
print(df_filtered['YIELD_RATE'].describe())

# Visualization of the Target Variable Distribution
plt.figure(figsize=(8, 5))
sns.histplot(df_filtered['YIELD_RATE'], bins=50, kde=True, color='skyblue')
plt.title('Distribution of Capped Monthly Egg Yield Rate')
plt.xlabel('Egg Yield Rate (Eggs per Hen per Month)')
plt.ylabel('Frequency')
plt.grid(axis='y', alpha=0.5)
plt.show()
# Out:
# Target YIELD_RATE capped at the 99th percentile: 31.00
# YIELD_RATE Descriptive Statistics after Capping:
# count    3382.000000
# mean       14.485608
# std         7.554840
# min         0.500000
# 25%        10.000000
# 50%        13.333333
# 75%        20.000000
# max        31.000000
# Name: YIELD_RATE, dtype: float64

# %% [markdown]
# ## 1.4 Feature Selection, Data Splitting, and Preprocessing Strategy (Revised)
#
# ### Data Splitting for Robust Evaluation
# For a comprehensive model comparison, particularly involving Deep Learning (DL), it is necessary to partition the data into three distinct sets: **Training (70%)**, **Validation (20%)**, and **Testing (10%)**.
#
# 1.  **Training Set (70%):** Used for fitting the model parameters (weights).
# 2.  **Validation Set (20%):** Used for **hyperparameter tuning** and **model selection** (e.g., determining optimal network architecture or applying early stopping in DL models) without influencing the final performance metric.
# 3.  **Testing Set (10%):** A completely unseen dataset used only once to provide the final, unbiased estimate of the model's generalization error.
#
# The split is performed in two sequential stages using `train_test_split` and maintains **geographic stratification** (by `province`) in both steps to ensure each data partition accurately reflects the overall regional distribution of the data.
#
# ### Feature Preprocessing
# As established, we utilize `Scikit-learn`'s `ColumnTransformer` to define the necessary pipelines:
# * **Categorical Features:** `OneHotEncoder` is applied to `province`, `district`, and `s11q2_2` (Month).
# * **Numerical Features:** Remaining missing values are handled via **Median Imputation**, followed by **Standardization** (`StandardScaler`). This normalization is non-negotiable for stable Deep Learning model training.

# %%
# Define Features (X) and Target (Y)
features = ['province', 'district', 's11q2_2', 's11q2_3', 's11q2_6', 's11q2_7', 's11q2_8', 's11q2_9']
target = 'YIELD_RATE'

X = df_filtered[features]
Y = df_filtered[target]

# --- Step 1: Split 90% (Train+Validation) / 10% (Test) ---
X_temp, X_test, Y_temp, Y_test = train_test_split(
    X, Y, 
    test_size=0.10, 
    random_state=42, 
    stratify=X['province'] 
)

# --- Step 2: Split X_temp/Y_temp into 70% (Train) / 20% (Validation) ---
# The desired validation size is 20% of the original data. 
# Since X_temp is 90% of the original, we calculate the ratio: 20% / 90% = 0.2222
X_train, X_val, Y_train, Y_val = train_test_split(
    X_temp, Y_temp, 
    test_size=(0.20 / 0.90), # 22.22% of the temporary set
    random_state=42, 
    stratify=X_temp['province'] 
)

print("--- Final Data Split Proportions ---")
total_rows = len(X)
print(f"Total rows: {total_rows}")
print(f"Train Set: {len(X_train)} rows ({len(X_train)/total_rows:.2f})")
print(f"Validation Set: {len(X_val)} rows ({len(X_val)/total_rows:.2f})")
print(f"Test Set: {len(X_test)} rows ({len(X_test)/total_rows:.2f})")

# Define feature pipelines (same as before)
categorical_features = ['province', 'district', 's11q2_2']
numerical_features = ['s11q2_3', 's11q2_6', 's11q2_7', 's11q2_8', 's11q2_9']

preprocessor = ColumnTransformer(
    transformers=[
        ('cat', OneHotEncoder(handle_unknown='ignore', sparse_output=False), categorical_features),
        ('num', Pipeline([
            ('imputer', SimpleImputer(strategy='median')), 
            ('scaler', StandardScaler())
        ]), numerical_features)
    ],
    remainder='drop'
)

# Fit the preprocessor ONLY on the training data and transform all three sets
X_train_processed = preprocessor.fit_transform(X_train)
X_val_processed = preprocessor.transform(X_val)
X_test_processed = preprocessor.transform(X_test)

# Convert outputs to numpy arrays for consistent input into TensorFlow
Y_train_array = Y_train.values
Y_val_array = Y_val.values
Y_test_array = Y_test.values
N_FEATURES = X_train_processed.shape[1]

print("\n--- Processed Data Shapes ---")
print(f"X_train_processed shape: {X_train_processed.shape}")
print(f"X_val_processed shape: {X_val_processed.shape}")
print(f"X_test_processed shape: {X_test_processed.shape}\n")

print(f"Y_train_array shape: {Y_train_array.shape}")
print(f"Y_val_array shape: {Y_val_array.shape}")
print(f"Y_test_array shape: {Y_test_array.shape}\n")

print(f"Total features after One-Hot Encoding: {N_FEATURES}")
# Out:
# --- Final Data Split Proportions ---
# Total rows: 3382
# Train Set: 2366 rows (0.70)
# Validation Set: 677 rows (0.20)
# Test Set: 339 rows (0.10)
#
# --- Processed Data Shapes ---
# X_train_processed shape: (2366, 52)
# X_val_processed shape: (677, 52)
# X_test_processed shape: (339, 52)
#
# Y_train_array shape: (2366,)
# Y_val_array shape: (677,)
# Y_test_array shape: (339,)
#
# Total features after One-Hot Encoding: 52

# %% [markdown]
# As we can see from above output, the data has been successfully partitioned and preprocessed into three distinct sets: Training, Validation, and Testing. The use of a dedicated validation set is critical for the rigorous development of the Deep Learning architecture, allowing for iterative tuning of hyperparameters like learning rate, number of layers, and regularization without contaminating the final performance assessment.
#
# | Data Set | Rows | Columns (Features) | State | Purpose |
# | :--- | :--- | :--- | :--- | :--- |
# | $\mathbf{X}_{\text{train}}$ | $\sim 70\%$ | $\mathbf{N}$ | Standardized/One-Hot Encoded | **Model Training** (Fitting parameters) |
# | $\mathbf{X}_{\text{val}}$ | $\sim 20\%$ | $\mathbf{N}$ | Standardized/One-Hot Encoded | **Hyperparameter Tuning** (Model selection) |
# | $\mathbf{X}_{\text{test}}$ | $\sim 10\%$ | $\mathbf{N}$ | Standardized/One-Hot Encoded | **Final Evaluation** (Unbiased performance) |
#
# The feature matrix now contains normalized numerical features and One-Hot Encoded categorical features, ensuring optimal conditions for both Traditional ML (Random Forest) and Deep Learning (MLP) experiments.

# %% [markdown]
# # Part 2: Traditional Machine Learning Experiments

# %% [markdown]
# In this pat two of our notebook, we build two traditional ML models (Linear Regression and Random Forest Regressor) and conduct experiments by tuning hyperparameters.
#
# Let's define a function to evaluate models and store results, ensuring consistency across all 14 traditional ML experiments for two models.

# %%
# A results storage for traditional ML experiments
results_ml = [] 

def evaluate_and_store(model_name, experiment_name, model, X_test, Y_test, notes=""):
    """Evaluates the model and stores results in the global list."""
    
    # Ensure the model is trained before evaluation
    if not hasattr(model, 'predict'):
        print(f"Warning: Model {model_name} not trained.")
        return

    Y_pred = model.predict(X_test)
    
    # Use the recommended root_mean_squared_error function
    rmse = root_mean_squared_error(Y_test, Y_pred) 
    r2 = r2_score(Y_test, Y_pred)
    
    results_ml.append({
        'Model': model_name,
        'Experiment': experiment_name,
        'Hyperparameters/Settings': str(model.get_params(deep=True)),
        'RMSE': f"{rmse:.4f}",
        'R2 Score': f"{r2:.4f}",
        'Notes': notes
    })

    print(f"-> {experiment_name}: RMSE={rmse:.4f}, R2={r2:.4f}")

    # Visualization of results (R2 and RMSE)
    plt.figure(figsize=(6,3))
    plt.bar(['RMSE', 'R²'], [rmse, r2], color=['blue', 'green'])
    plt.title(experiment_name)
    plt.ylabel('Score')
    plt.ylim(0, max(rmse, 1))
    plt.show()

    return rmse, r2

# %% [markdown]
# ## 2.1 Model 1: Linear Regression (LR)
#
# ### LR-1: Standard OLS Baseline
#
# Our first LR model establishes the performance floor of a simple linear model. If this model performs poorly, it justifies the need for complex non-linear techniques.

# %%
lr_model_1 = LinearRegression()
lr_model_1.fit(X_train_processed, Y_train_array)
evaluate_and_store("Linear Regression", "LR-1: Standard OLS Baseline", lr_model_1, X_test_processed, Y_test_array)
# Out:
# -> LR-1: Standard OLS Baseline: RMSE=6.4203, R2=0.2411
# (6.4202771432301455, 0.24110039501983693)

# %% [markdown]
# From above results, the baseline Linear Regression model (LR-1) achieved an RMSE of 6.42 and an $R^2$ of 0.24. This relatively low $R^2$ indicates that the simple linear model explains only a small portion of the variance in egg yield rate. I suspect that the likely reason is that the relationship between the input features and the target variable is not strictly linear, and the model cannot capture complex interactions or non-linear effects present in the data.

# %% [markdown]
# ### LR-2: Ridge Regularization ($\mathbf{L_2}$)
#
# To improve performance, a logical next step is to introduce regularization. Regularization can help address multicollinearity from one-hot encoded features.
#
# Ridge Regression addresses multicollinearity, which is highly probable due to the many One-Hot Encoded features, by adding an $\mathbf{L_2}$ penalty to the loss function. We use a small $\alpha$ value as a test.

# %%
lr_model_2 = Ridge(alpha=1.0) # Small alpha for test
lr_model_2.fit(X_train_processed, Y_train_array)
evaluate_and_store("Linear Regression", "LR-2: Ridge Regularization (alpha=1.0)", lr_model_2, X_test_processed, Y_test_array)
# Out:
# -> LR-2: Ridge Regularization (alpha=1.0): RMSE=6.4177, R2=0.2417
# (6.417686820322502, 0.24171264225715272)

# %% [markdown]
# The above model (LR-2) achieved an RMSE of 6.42 and an $R^2$ of 0.24, which is nearly identical to the baseline Linear Regression (LR-1). This suggests that introducing L2 regularization with the tested $\alpha=1.0$ did not significantly impact model performance. The likely reason is that the underlying relationship between features and the target variable is not strongly affected by multicollinearity or large coefficients, or the regularization strength is not optimal for this dataset.

# %% [markdown]
# ### LR-3: Log Transformation of Features
#
# Applying log transformation to skewed numerical features can help linear models capture non-linear relationships and reduce the impact of outliers. Here, we apply a log transformation to `s11q2_3` (Number of Hens) and optionally to other skewed features before fitting the Ridge Regression.

# %%
# Apply log transformation to selected features
X_train_log = X_train.copy()
X_test_log = X_test.copy()
X_train_log['s11q2_3'] = np.log1p(X_train_log['s11q2_3'])
X_test_log['s11q2_3'] = np.log1p(X_test_log['s11q2_3'])

X_train_log_processed = preprocessor.fit_transform(X_train_log)
X_test_log_processed = preprocessor.transform(X_test_log)


lr_model_3 = Ridge(alpha=1.0)
lr_model_3.fit(X_train_log_processed, Y_train_array)
evaluate_and_store("Linear Regression", "LR-3: Ridge with Log-Transformed (s11q2_3)", lr_model_3, X_test_log_processed, Y_test_array)
# Out:
# -> LR-3: Ridge with Log-Transformed (s11q2_3): RMSE=6.4036, R2=0.2450
# (6.403593878231541, 0.24503931324976624)

# %% [markdown]
# ### LR-4: Location Impact Test
#
# As we can see from above experiment, the RMSE remains goes down a little bit from 6.42 to 6.40. The R2  remains the same. This prompt the use of a diddferent approach: isolation of some predictive locations using numerical features only and the baseline LR model from experiment LR-1 to assess the effect.
#
# This experiment isolates the predictive power of non-geographic features by training the OLS model without the One-Hot Encoded province, district, and s11q2_2 features.

# %%
# Create a temporary preprocessor without categorical features
numerical_features_only = ['s11q2_3', 's11q2_6', 's11q2_7', 's11q2_8', 's11q2_9']
preprocessor_num = ColumnTransformer(
    transformers=[
        ('num', Pipeline([('imputer', SimpleImputer(strategy='median')), ('scaler', StandardScaler())]), numerical_features_only)
    ],
    remainder='drop'
)

# transform the data
X_train_num = preprocessor_num.fit_transform(X_train)
X_test_num = preprocessor_num.transform(X_test)

lr_model_4 = LinearRegression()
lr_model_4.fit(X_train_num, Y_train_array)
evaluate_and_store("Linear Regression", "LR-4: Location Impact Test", lr_model_4, X_test_num, Y_test_array, 
                   notes="Tested predictive power of numerical features only.")
# Out:
# -> LR-4: Location Impact Test: RMSE=6.5614, R2=0.2074
# (6.561384725845903, 0.2073749708687026)

# %% [markdown]
# From this experiment, we see that the RMSE actually does up (6.56) while the R2 goes down to 0.20. This means that this test produced an underperforming model compared to the previous experiments.

# %% [markdown]
# ### LR-5: Non-Linear Feature Transformation
#
# Since the relationship between hen numbers and yield may be non-linear (e.g., economies/diseconomies of scale), we apply a $\text{log}(x)$ transformation to the highly skewed s11q2_3 (Number of Hens) feature.

# %%
# Define a custom transformer for log-transforming 's11q2_3'
class LogTransformer:
    def fit(self, X, y=None):
        return self
    def transform(self, X):
        X_copy = X.copy()
        # Add a tiny constant to avoid log(0), although s11q2_3 > 0 due to filtering
        X_copy['s11q2_3'] = np.log1p(X_copy['s11q2_3']) 
        return X_copy

# Recreate pipeline with the log transformer applied
preprocessor_log = ColumnTransformer(
    transformers=[
        ('cat', OneHotEncoder(handle_unknown='ignore', sparse_output=False), categorical_features),
        ('num', Pipeline([
            ('imputer', SimpleImputer(strategy='median')), 
            ('scaler', StandardScaler())
        ]), numerical_features)
    ],
    remainder='drop'
)

# Apply the Log Transformation manually before processing
X_train_log = X_train.copy()
X_test_log = X_test.copy()
X_train_log['s11q2_3'] = np.log1p(X_train_log['s11q2_3'])
X_test_log['s11q2_3'] = np.log1p(X_test_log['s11q2_3'])

X_train_log_processed = preprocessor_log.fit_transform(X_train_log)
X_test_log_processed = preprocessor_log.transform(X_test_log)


lr_model_5 = LinearRegression()
lr_model_5.fit(X_train_log_processed, Y_train_array)
evaluate_and_store("Linear Regression", "LR-5: Log-Transform (s11q2_3)", lr_model_5, X_test_log_processed, Y_test_array,
                   notes="Tested non-linear log transform on Number of Hens (s11q2_3).")
# Out:
# -> LR-5: Log-Transform (s11q2_3): RMSE=6.4060, R2=0.2445
# (6.406014214437753, 0.2444685075305595)

# %% [markdown]
# In this experiment, the model produced is better that the one from previous experiment but on-par with the ones from previous experiments.

# %% [markdown]
# ## LR-6: Feature Interaction Test
#
# Linear models assume additive effects. This experiment uses PolynomialFeatures to introduce interaction terms (degree 2) between all numerical features, allowing the LR model to capture simple non-linear relationships.

# %%
# Create a full pipeline including interaction terms
full_pipeline_interaction = Pipeline(steps=[
    ('preprocessor', preprocessor),
    ('poly', PolynomialFeatures(degree=2, include_bias=False, interaction_only=True)), # Only interactions
    ('regressor', LinearRegression())
])

lr_model_6 = full_pipeline_interaction.fit(X_train, Y_train_array)
evaluate_and_store("Linear Regression", "LR-6: Feature Interaction (Poly Degree 2)", lr_model_6, X_test, Y_test_array,
                   notes="Added all 2nd degree interaction terms to features.")
# Out:
# -> LR-6: Feature Interaction (Poly Degree 2): RMSE=8.5308, R2=-0.3399
# (8.530821921800335, -0.33985724250015337)

# %% [markdown]
# An increase in RMSE and decrease of R2 to negatives suggests that this model is performing poorly compared to all previous models. This means we can try something else.

# %% [markdown]
# ### LR-7: Feature Selection using Lasso
#
# Using the optimized Lasso model, we explicitly identify and list the features retained (non-zero coefficients), providing a crucial first step in feature importance analysis.

# %%
# Re-run Lasso with a slightly tighter alpha for clearer selection
lr_lasso_final = Lasso(alpha=0.005, max_iter=10000) 
lr_lasso_final.fit(X_train_processed, Y_train_array)

# Get feature names after preprocessing
feature_names = preprocessor.get_feature_names_out()

# Identify features with non-zero coefficients
retained_features = feature_names[lr_lasso_final.coef_ != 0]

print(f"\nTop 10 features retained by Lasso (LR-7):\n{retained_features[:10]}")

evaluate_and_store("Linear Regression", "LR-7: Feature Selection using Lasso", lr_lasso_final, X_test_processed, Y_test_array,
                   notes=f"Identified {len(retained_features)} features with non-zero coefficients.")
# Out:
# Top 10 features retained by Lasso (LR-7):
# ['cat__province_Kigali' 'cat__province_North' 'cat__province_South'
#  'cat__province_West' 'cat__district_Bugesera' 'cat__district_Burera'
#  'cat__district_Gakenke' 'cat__district_Gasabo' 'cat__district_Gatsibo'
#  'cat__district_Gicumbi']
# -> LR-7: Feature Selection using Lasso: RMSE=6.4213, R2=0.2409
# (6.421274736466932, 0.24086453855630063)

# %% [markdown]
# These results from the experiment LR-7 indicates that the model barely improves. It still average at 6.42 RMSE and 0.24 R2. The LR model barely achieved the best RMSE of 6.40 and the best R2 of 0.20

# %% [markdown]
# ## 2.2 Model 2: Random Forest Regressor (RFR)

# %% [markdown]
# ### RFR-1: Default Hyperparameter Benchmark
#
# This experiment establishes the initial performance of the RFR ensemble model. Due to its robustness, the default RFR often serves as a powerful benchmark for DL models. From this model, we can see whether we get an improvement to the LR models we tried above.

# %%
rfr_model_1 = RandomForestRegressor(random_state=42)
rfr_model_1.fit(X_train_processed, Y_train_array)
evaluate_and_store("Random Forest", "RFR-1: Default Hyperparameter Benchmark", rfr_model_1, X_test_processed, Y_test_array)
# Out:
# -> RFR-1: Default Hyperparameter Benchmark: RMSE=5.9070, R2=0.3576
# (5.906966802786168, 0.3575995510090999)

# %% [markdown]
# The results shows that we are stepping to the right direction. The RMSE improved by declining to 5.90 and the R2 improved as well to 0.35.

# %% [markdown]
# ### RFR-2: Tree Depth Tuning ($\mathbf{max\_depth=10}$)
#
# Next, let's try controlling the max_depth hyperparameter. This is because the lower R2 we had previously, might indicate the issue of overfitting.
#
# Controlling max_depth (the complexity of individual trees) is essential to prevent overfitting. We limit the depth to 10 to encourage the forest to generalize better.

# %%
rfr_model_2 = RandomForestRegressor(max_depth=10, random_state=42)
rfr_model_2.fit(X_train_processed, Y_train_array)
evaluate_and_store("Random Forest", "RFR-2: Tree Depth Tuning (max_depth=10)", rfr_model_2, X_test_processed, Y_test_array)
# Out:
# -> RFR-2: Tree Depth Tuning (max_depth=10): RMSE=5.6967, R2=0.4025
# (5.6966882835640655, 0.4025223178145778)

# %% [markdown]
# Excellent! Now we managed to bring down RMSE to 5.69 and improved R2 to 0.40. Next, let's try to reduce the ensemble size by tuning the `n_estimators`

# %% [markdown]
# ### RFR-3: Ensemble Size Tuning ($\mathbf{n\_estimators=500}$)
#
# Increasing n_estimators (number of trees) typically improves performance by reducing variance, up to a point, at the cost of computational time. We test 500 trees vs. the default (typically 100).

# %%
rfr_model_3 = RandomForestRegressor(max_depth=10, n_estimators=500, random_state=42, n_jobs=-1)
rfr_model_3.fit(X_train_processed, Y_train_array)
evaluate_and_store("Random Forest", "RFR-3: Ensemble Size (max_depth=10, n_estimators=500)", rfr_model_3, X_test_processed, Y_test_array)
# Out:
# -> RFR-3: Ensemble Size (max_depth=10, n_estimators=500): RMSE=5.6488, R2=0.4125
# (5.648759134564537, 0.4125337940526824)

# %% [markdown]
# Once again, we see that the RMSE reduced and the R2 increased. Let's use this as the foundation and optimize the model using grid search.

# %% [markdown]
# ### RFR-5: Grid Search Optimization
#
# This experiment systematically searches a defined hyperparameter space to find the overall optimal RFR configuration, demonstrating a rigorous optimization strategy. Due to time constraints, the grid is kept small.

# %%
param_grid = {
    'n_estimators': [100, 300, 500, 600],
    'max_depth': [10, 20, 30],
    'min_samples_split': [5, 10]
}
rfr_model_5 = GridSearchCV(RandomForestRegressor(random_state=42), param_grid, cv=KFold(n_splits=3, shuffle=True, random_state=42), scoring='neg_root_mean_squared_error', n_jobs=-1)
rfr_model_5.fit(X_train_processed, Y_train_array)
optimal_rfr = rfr_model_5.best_estimator_

evaluate_and_store("Random Forest", "RFR-5: Grid Search Optimization", optimal_rfr, X_test_processed, Y_test_array,
                   notes=f"Optimal Params: {rfr_model_5.best_params_}")
# Out:
# -> RFR-5: Grid Search Optimization: RMSE=5.6417, R2=0.4140
# (5.641659105503704, 0.4140096600667551)

# %% [markdown]
# This experiment shows that trying different hyperparameter optimizations barely proved to changed anything. We can see that the RMSE is still at 5.64 and R2 is still at 0.41. In the next steps, let's analyse the importance of features to see what we can improve.

# %% [markdown]
# ### RFR-6: Feature Importance Analysis
#
# Let's extract the Gini Importance scores from the optimal RFR model (Exp. RFR-5). This is the most crucial interpretability result for the extension services, providing a ranked list of factors influencing egg yield.

# %%
# Extract Feature Importances
importances = optimal_rfr.feature_importances_
feature_names_full = preprocessor.get_feature_names_out()
sorted_idx = importances.argsort()[::-1]

# Display top 10 features
top_10_features = feature_names_full[sorted_idx][:10]
top_10_importances = importances[sorted_idx][:10]

# Visualization of Feature Importance
plt.figure(figsize=(10, 6))
sns.barplot(x=top_10_importances, y=top_10_features, palette="viridis", hue=top_10_importances)
plt.title('Top 10 Feature Importance (Optimal Random Forest)')
plt.xlabel('Gini Importance')
plt.ylabel('Feature')
plt.show()

evaluate_and_store("Random Forest", "RFR-6: Feature Importance Analysis", optimal_rfr, X_test_processed, Y_test_array,
                   notes=f"Top 3 Features: {top_10_features[:3].tolist()}")
# Out:
# -> RFR-6: Feature Importance Analysis: RMSE=5.6417, R2=0.4140
# (5.641659105503704, 0.4140096600667551)

# %% [markdown]
# This shows that features `s11q2_6` (Number of eggs sold) and `s11q2_3` (Number of laying hens) are the highly ranked important features. It is even much more understandable as these are the top estimators of productivity rate. However, there is a limitation as we don't know how many hens died.

# %% [markdown]
# ## RFR-7: Algorithm Comparison (Gradient Boosting Regressor)
#
# Let's conduct a final experiment on RF by directly comparing the RFR against another ensemble method, Gradient Boosting Regressor (GBR), tests if the sequential, corrective approach of boosting provides a performance advantage over the parallel, averaging approach of bagging.

# %%
gbr_model = GradientBoostingRegressor(n_estimators=100, learning_rate=0.1, max_depth=3, random_state=42)
gbr_model.fit(X_train_processed, Y_train_array)
evaluate_and_store("Gradient Boosting Regressor", "RFR-7: Gradient Boosting Regressor for comparison", gbr_model, X_test_processed, Y_test_array,
                   notes="Comparison model to RFR (GBR, a boosting algorithm).")
# Out:
# -> RFR-7: Gradient Boosting Regressor for comparison: RMSE=5.4785, R2=0.4474
# (5.4785342702624, 0.4474067942216572)

# %% [markdown]
# This model performs well but not better the other previous models. It managed to get an RMSE of 5.48 and R2 of 0.44. It averages to the performance of all other RFR models

# %% [markdown]
# As a conclusion, We observe that the RFR models outperforms the LR models. This is due to the sofisticated structure of RFR models and their ability to capture non-linear relationships in the data.

# %% [markdown]
# # Part 3: Deep Learning Experiments (TensorFlow)
#
# In this part, let's define functions for creating standard Sequential and Functional models and a function to run and record DL experiments, focusing on monitoring validation loss.
#
# The goal is to try to get a better performing model while also comparing DL models performance or traditional ML models.

# %%
results_dl = []
EPOCHS = 50
BATCH_SIZE = 64
VERBOSE = 1  # Verbose training to see results

def create_sequential_model(n_features, layers, activation='relu', optimizer=Adam(learning_rate=0.001)):
    """Creates a standard Sequential MLP."""
    model = Sequential(name='Sequential_MLP')
    for units in layers:
        model.add(Dense(units, activation=activation))
    model.add(Dense(1, activation='linear')) # Regression output layer
    model.compile(optimizer=optimizer, loss='mse', metrics=['mae', tf.keras.metrics.RootMeanSquaredError(name='rmse')])
    return model

def create_functional_model(n_features, layers, activation='relu', optimizer=Adam(learning_rate=0.001), regularizer=None, dropout_rate=0.0):
    """Creates a custom Functional MLP."""
    input_tensor = Input(shape=(n_features,), name='Input_Layer')
    x = input_tensor
    for units in layers:
        x = Dense(units, activation=activation, kernel_regularizer=regularizer)(x)
        if dropout_rate > 0.0:
            x = Dropout(dropout_rate)(x)
    output_tensor = Dense(1, activation='linear', name='Output_Layer')(x)
    
    model = Model(inputs=input_tensor, outputs=output_tensor, name='Functional_MLP')
    model.compile(optimizer=optimizer, loss='mse', metrics=['mae', tf.keras.metrics.RootMeanSquaredError(name='rmse')])
    return model


# Plotting function for DL metrics
def plot_dl_metrics(history, model, X_train, Y_train, X_val, Y_val):
    # RMSE and MAE are available directly
    epochs = range(1, len(history.history['rmse']) + 1)
    plt.figure(figsize=(16, 8))

    # Plot RMSE
    plt.subplot(2, 3, 1)
    plt.plot(epochs, history.history['rmse'], label='Train RMSE')
    plt.plot(epochs, history.history['val_rmse'], label='Val RMSE')
    plt.xlabel('Epoch')
    plt.ylabel('RMSE')
    plt.title('RMSE over Epochs')
    plt.legend()

    # Plot MAE
    plt.subplot(2, 3, 2)
    plt.plot(epochs, history.history['mae'], label='Train MAE')
    plt.plot(epochs, history.history['val_mae'], label='Val MAE')
    plt.xlabel('Epoch')
    plt.ylabel('MAE')
    plt.title('MAE over Epochs')
    plt.legend()

    # Compute R2 for each epoch (not tracked by Keras)
    train_r2 = []
    val_r2 = []
    for epoch in epochs:
        model.set_weights(history.model.get_weights())
        Y_train_pred = model.predict(X_train, verbose=0).flatten()
        Y_val_pred = model.predict(X_val, verbose=0).flatten()
        train_r2.append(r2_score(Y_train, Y_train_pred))
        val_r2.append(r2_score(Y_val, Y_val_pred))

    # Plot R2
    plt.subplot(2, 3, 3)
    plt.plot(epochs, train_r2, label='Train R2')
    plt.plot(epochs, val_r2, label='Val R2')
    plt.xlabel('Epoch')
    plt.ylabel('R2 Score')
    plt.title('R2 over Epochs')
    plt.legend()

    # Plot Loss (MSE)
    plt.subplot(2, 1, 2)
    plt.plot(epochs, history.history['loss'], label='Train Loss (MSE)')
    plt.plot(epochs, history.history['val_loss'], label='Val Loss (MSE)')
    plt.xlabel('Epoch')
    plt.ylabel('Loss (MSE)')
    plt.title('Loss and Val Loss over Epochs')
    plt.legend()

    plt.tight_layout()
    plt.show()

# Run DL Experiment Function
def run_dl_experiment(model, experiment_name, X_train, Y_train, X_val, Y_val, epochs=EPOCHS, callbacks=None):
    """Trains, evaluates, and records the DL experiment."""
    
    # Train the model
    history = model.fit(
        X_train, Y_train,
        epochs=epochs,
        batch_size=BATCH_SIZE,
        validation_data=(X_val, Y_val),
        callbacks=callbacks,
        verbose=VERBOSE
    )

    # Evaluate on the Test Set
    metrics = model.evaluate(X_test_processed, Y_test_array, verbose=VERBOSE)
    rmse = metrics[2] # Assuming RMSE is the 3rd metric (index 2)
    
    # Calculate R2 (requires prediction)
    Y_pred_test = model.predict(X_test_processed, verbose=0).flatten()
    r2 = r2_score(Y_test_array, Y_pred_test)

    # Store results
    results_dl.append({
        'Model': model.name,
        'Experiment': experiment_name,
        'Hyperparameters/Settings': f"Layers:{model.layers[1].get_config().get('units')}, LR:{model.optimizer.get_config().get('learning_rate', 'N/A')}",
        'RMSE': f"{rmse:.4f}",
        'R2 Score': f"{r2:.4f}",
        'Final Val Loss': f"{history.history['val_loss'][-1]:.4f}",
        'Notes': model.name.split('_')[0]
    })
    print(f"-> {experiment_name}: Test RMSE={rmse:.4f}, Test R2={r2:.4f}")

    plot_dl_metrics(history, model, X_train_processed, Y_train_array, X_val_processed, Y_val_array)
    
    return history

# %% [markdown]
# ## 3.1 Model 3: Multi-Layer Perceptron (MLP) - Sequential API

# %% [markdown]
# ### MLP-S-1: Minimalist Baseline (Single Layer)
#
# Sets the basic DL performance floor. A single hidden layer with small capacity (32 neurons) determines if the linear LR or RFR model is sufficient or if even minimal depth offers improvement.

# %%
model_s1 = create_sequential_model(n_features=N_FEATURES, layers=[32])
history_s1 = run_dl_experiment(model_s1, "MLP-S-1: Minimalist Baseline (1x32)", X_train_processed, Y_train_array, X_val_processed, Y_val_array)
# Out:
# Epoch 1/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 75ms/step - loss: 249.6159 - mae: 13.8396 - rmse: 15.7992 - val_loss: 234.7712 - val_mae: 13.2973 - val_rmse: 15.3222
# Epoch 2/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - loss: 223.9914 - mae: 12.9089 - rmse: 14.9663 - val_loss: 206.1400 - val_mae: 12.2213 - val_rmse: 14.3576
# Epoch 3/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 61ms/step - loss: 191.5812 - mae: 11.6584 - rmse: 13.8413 - val_loss: 170.6064 - val_mae: 10.7736 - val_rmse: 13.0616
# Epoch 4/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 64ms/step - loss: 154.0881 - mae: 10.1159 - rmse: 12.4132 - val_loss: 133.2461 - val_mae: 9.1162 - val_rmse: 11.5432
# Epoch 5/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 55ms/step - loss: 117.8624 - mae: 8.4824 - rmse: 10.8564 - val_loss: 100.4151 - val_mae: 7.5569 - val_rmse: 10.0207
# Epoch 6/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 68ms/step - loss: 88.7617 - mae: 7.1246 - rmse: 9.4213 - val_loss: 76.5065 - val_mae: 6.4670 - val_rmse: 8.7468
# Epoch 7/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 64ms/step - loss: 68.6521 - mae: 6.2475 - rmse: 8.2857 - val_loss: 62.1063 - val_mae: 5.8801 - val_rmse: 7.8808
# Epoch 8/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 63ms/step - loss: 56.8723 - mae: 5.7668 - rmse: 7.5414 - val_loss: 54.1984 - val_mae: 5.5670 - val_rmse: 7.3620
# Epoch 9/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 67ms/step - loss: 50.5412 - mae: 5.5307 - rmse: 7.1092 - val_loss: 50.1023 - val_mae: 5.4281 - val_rmse: 7.0783
# Epoch 10/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - loss: 47.1685 - mae: 5.4142 - rmse: 6.8679 - val_loss: 47.8338 - val_mae: 5.3678 - val_rmse: 6.9162
# Epoch 11/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - loss: 45.1343 - mae: 5.3341 - rmse: 6.7182 - val_loss: 46.4561 - val_mae: 5.3281 - val_rmse: 6.8159
# Epoch 12/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - loss: 43.7402 - mae: 5.2725 - rmse: 6.6136 - val_loss: 45.5427 - val_mae: 5.2899 - val_rmse: 6.7485
# Epoch 13/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - loss: 42.8343 - mae: 5.2273 - rmse: 6.5448 - val_loss: 44.8646 - val_mae: 5.2608 - val_rmse: 6.6981
# Epoch 14/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - loss: 42.1218 - mae: 5.1881 - rmse: 6.4901 - val_loss: 44.3904 - val_mae: 5.2341 - val_rmse: 6.6626
# Epoch 15/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - loss: 41.5772 - mae: 5.1497 - rmse: 6.4480 - val_loss: 44.0560 - val_mae: 5.2198 - val_rmse: 6.6375
# Epoch 16/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - loss: 41.1409 - mae: 5.1273 - rmse: 6.4141 - val_loss: 43.7509 - val_mae: 5.1965 - val_rmse: 6.6144
# Epoch 17/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 56ms/step - loss: 40.8338 - mae: 5.0985 - rmse: 6.3901 - val_loss: 43.5302 - val_mae: 5.1822 - val_rmse: 6.5977
# Epoch 18/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - loss: 40.5404 - mae: 5.0735 - rmse: 6.3671 - val_loss: 43.3374 - val_mae: 5.1654 - val_rmse: 6.5831
# Epoch 19/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - loss: 40.2985 - mae: 5.0548 - rmse: 6.3481 - val_loss: 43.1686 - val_mae: 5.1528 - val_rmse: 6.5703
# Epoch 20/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - loss: 40.0994 - mae: 5.0490 - rmse: 6.3324 - val_loss: 42.9998 - val_mae: 5.1453 - val_rmse: 6.5574
# Epoch 21/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - loss: 39.9219 - mae: 5.0209 - rmse: 6.3184 - val_loss: 42.8813 - val_mae: 5.1291 - val_rmse: 6.5484
# Epoch 22/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - loss: 39.7714 - mae: 5.0180 - rmse: 6.3065 - val_loss: 42.7663 - val_mae: 5.1257 - val_rmse: 6.5396
# Epoch 23/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 67ms/step - loss: 39.5998 - mae: 5.0004 - rmse: 6.2928 - val_loss: 42.6797 - val_mae: 5.1209 - val_rmse: 6.5330
# Epoch 24/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 56ms/step - loss: 39.4389 - mae: 4.9837 - rmse: 6.2800 - val_loss: 42.5861 - val_mae: 5.1069 - val_rmse: 6.5258
# Epoch 25/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - loss: 39.3157 - mae: 4.9649 - rmse: 6.2702 - val_loss: 42.4707 - val_mae: 5.0926 - val_rmse: 6.5170
# Epoch 26/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - loss: 39.1807 - mae: 4.9558 - rmse: 6.2594 - val_loss: 42.4095 - val_mae: 5.0975 - val_rmse: 6.5123
# Epoch 27/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - loss: 39.0730 - mae: 4.9480 - rmse: 6.2508 - val_loss: 42.2685 - val_mae: 5.0884 - val_rmse: 6.5014
# Epoch 28/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - loss: 38.9792 - mae: 4.9298 - rmse: 6.2433 - val_loss: 42.1511 - val_mae: 5.0750 - val_rmse: 6.4924
# Epoch 29/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - loss: 38.8413 - mae: 4.9346 - rmse: 6.2323 - val_loss: 42.0366 - val_mae: 5.0647 - val_rmse: 6.4836
# Epoch 30/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 57ms/step - loss: 38.7342 - mae: 4.9141 - rmse: 6.2237 - val_loss: 41.9521 - val_mae: 5.0515 - val_rmse: 6.4770
# Epoch 31/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - loss: 38.5809 - mae: 4.9002 - rmse: 6.2114 - val_loss: 41.8151 - val_mae: 5.0447 - val_rmse: 6.4665
# Epoch 32/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - loss: 38.4562 - mae: 4.8914 - rmse: 6.2013 - val_loss: 41.6770 - val_mae: 5.0346 - val_rmse: 6.4558
# Epoch 33/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - loss: 38.3182 - mae: 4.8755 - rmse: 6.1902 - val_loss: 41.5518 - val_mae: 5.0221 - val_rmse: 6.4461
# Epoch 34/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 60ms/step - loss: 38.1894 - mae: 4.8733 - rmse: 6.1798 - val_loss: 41.4268 - val_mae: 5.0172 - val_rmse: 6.4364
# Epoch 35/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 71ms/step - loss: 38.0885 - mae: 4.8641 - rmse: 6.1716 - val_loss: 41.2695 - val_mae: 5.0054 - val_rmse: 6.4241
# Epoch 36/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 63ms/step - loss: 37.9654 - mae: 4.8266 - rmse: 6.1616 - val_loss: 41.2019 - val_mae: 4.9922 - val_rmse: 6.4189
# Epoch 37/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - loss: 37.8010 - mae: 4.8438 - rmse: 6.1483 - val_loss: 41.0675 - val_mae: 4.9957 - val_rmse: 6.4084
# Epoch 38/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 55ms/step - loss: 37.6580 - mae: 4.8225 - rmse: 6.1366 - val_loss: 40.8953 - val_mae: 4.9732 - val_rmse: 6.3949
# Epoch 39/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 57ms/step - loss: 37.5532 - mae: 4.8131 - rmse: 6.1281 - val_loss: 40.7364 - val_mae: 4.9627 - val_rmse: 6.3825
# Epoch 40/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - loss: 37.4080 - mae: 4.7909 - rmse: 6.1162 - val_loss: 40.6953 - val_mae: 4.9651 - val_rmse: 6.3793
# Epoch 41/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - loss: 37.2906 - mae: 4.8024 - rmse: 6.1066 - val_loss: 40.5161 - val_mae: 4.9485 - val_rmse: 6.3652
# Epoch 42/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - loss: 37.1402 - mae: 4.7854 - rmse: 6.0943 - val_loss: 40.3622 - val_mae: 4.9301 - val_rmse: 6.3531
# Epoch 43/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 55ms/step - loss: 36.9886 - mae: 4.7567 - rmse: 6.0818 - val_loss: 40.2839 - val_mae: 4.9327 - val_rmse: 6.3470
# Epoch 44/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 57ms/step - loss: 36.8668 - mae: 4.7581 - rmse: 6.0718 - val_loss: 40.1831 - val_mae: 4.9350 - val_rmse: 6.3390
# Epoch 45/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - loss: 36.7386 - mae: 4.7552 - rmse: 6.0612 - val_loss: 40.0752 - val_mae: 4.9289 - val_rmse: 6.3305
# Epoch 46/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 60ms/step - loss: 36.6269 - mae: 4.7435 - rmse: 6.0520 - val_loss: 39.9047 - val_mae: 4.9099 - val_rmse: 6.3170
# Epoch 47/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 56ms/step - loss: 36.4946 - mae: 4.7310 - rmse: 6.0411 - val_loss: 39.8415 - val_mae: 4.9009 - val_rmse: 6.3120
# Epoch 48/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 55ms/step - loss: 36.3632 - mae: 4.7169 - rmse: 6.0302 - val_loss: 39.7164 - val_mae: 4.8862 - val_rmse: 6.3021
# Epoch 49/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 66ms/step - loss: 36.2792 - mae: 4.7111 - rmse: 6.0232 - val_loss: 39.6001 - val_mae: 4.8886 - val_rmse: 6.2929
# Epoch 50/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - loss: 36.1311 - mae: 4.7101 - rmse: 6.0109 - val_loss: 39.4934 - val_mae: 4.8815 - val_rmse: 6.2844
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 37.2993 - mae: 4.8827 - rmse: 6.1073
# -> MLP-S-1: Minimalist Baseline (1x32): Test RMSE=6.1073, Test R2=0.3133

# %% [markdown]
# These results suggests the DL baseline Sequential model above outperforms the LR models but it is still underperforming compared to RFR model. This is because the RFR models show lower RMSE and higher R2.

# %% [markdown]
# ### MLP-S-2: Optimal Depth Test (3 Layers)
#
# Next, let's increase the model complexity by adding layers (depth=3) while maintaining a moderate width (64 neurons). This tests the necessity of "deep" architecture for prediction.

# %%
model_s2 = create_sequential_model(n_features=N_FEATURES, layers=[64, 64, 64], optimizer=Adam(learning_rate=0.001))
history_s2 = run_dl_experiment(model_s2, "MLP-S-2: Optimal Depth Test (3x64)", X_train_processed, Y_train_array, X_val_processed, Y_val_array)
# Out:
# Epoch 1/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 78ms/step - loss: 217.4312 - mae: 12.6812 - rmse: 14.7455 - val_loss: 122.1773 - val_mae: 8.6851 - val_rmse: 11.0534
# Epoch 2/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 77ms/step - loss: 67.6602 - mae: 6.3114 - rmse: 8.2256 - val_loss: 58.7150 - val_mae: 5.7087 - val_rmse: 7.6626
# Epoch 3/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 72ms/step - loss: 48.8079 - mae: 5.4619 - rmse: 6.9863 - val_loss: 52.5613 - val_mae: 5.5564 - val_rmse: 7.2499
# Epoch 4/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 74ms/step - loss: 43.8910 - mae: 5.2454 - rmse: 6.6250 - val_loss: 49.4490 - val_mae: 5.4367 - val_rmse: 7.0320
# Epoch 5/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 72ms/step - loss: 41.6678 - mae: 5.1372 - rmse: 6.4551 - val_loss: 47.0697 - val_mae: 5.3249 - val_rmse: 6.8607
# Epoch 6/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 70ms/step - loss: 39.8898 - mae: 5.0228 - rmse: 6.3158 - val_loss: 45.5087 - val_mae: 5.2337 - val_rmse: 6.7460
# Epoch 7/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 70ms/step - loss: 38.5970 - mae: 4.9268 - rmse: 6.2126 - val_loss: 43.7503 - val_mae: 5.0313 - val_rmse: 6.6144
# Epoch 8/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 70ms/step - loss: 37.6772 - mae: 4.8358 - rmse: 6.1382 - val_loss: 43.1141 - val_mae: 5.0510 - val_rmse: 6.5661
# Epoch 9/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 72ms/step - loss: 36.6400 - mae: 4.7842 - rmse: 6.0531 - val_loss: 43.2331 - val_mae: 5.1083 - val_rmse: 6.5752
# Epoch 10/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 69ms/step - loss: 36.2239 - mae: 4.7057 - rmse: 6.0186 - val_loss: 41.5840 - val_mae: 4.8871 - val_rmse: 6.4486
# Epoch 11/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 71ms/step - loss: 35.1622 - mae: 4.6776 - rmse: 5.9298 - val_loss: 41.6383 - val_mae: 5.0099 - val_rmse: 6.4528
# Epoch 12/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 72ms/step - loss: 34.6652 - mae: 4.6105 - rmse: 5.8877 - val_loss: 40.5400 - val_mae: 4.9108 - val_rmse: 6.3671
# Epoch 13/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 76ms/step - loss: 33.8180 - mae: 4.5478 - rmse: 5.8153 - val_loss: 39.9604 - val_mae: 4.8338 - val_rmse: 6.3214
# Epoch 14/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 73ms/step - loss: 33.4773 - mae: 4.5339 - rmse: 5.7860 - val_loss: 39.6082 - val_mae: 4.8522 - val_rmse: 6.2935
# Epoch 15/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 71ms/step - loss: 32.5863 - mae: 4.4394 - rmse: 5.7084 - val_loss: 39.1698 - val_mae: 4.7718 - val_rmse: 6.2586
# Epoch 16/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 72ms/step - loss: 32.0179 - mae: 4.4079 - rmse: 5.6584 - val_loss: 39.8228 - val_mae: 4.8954 - val_rmse: 6.3105
# Epoch 17/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 72ms/step - loss: 31.2830 - mae: 4.3368 - rmse: 5.5931 - val_loss: 39.1272 - val_mae: 4.7258 - val_rmse: 6.2552
# Epoch 18/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 74ms/step - loss: 31.0127 - mae: 4.3296 - rmse: 5.5689 - val_loss: 38.9519 - val_mae: 4.7892 - val_rmse: 6.2411
# Epoch 19/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 81ms/step - loss: 30.3114 - mae: 4.2577 - rmse: 5.5056 - val_loss: 38.7295 - val_mae: 4.7618 - val_rmse: 6.2233
# Epoch 20/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 69ms/step - loss: 29.8466 - mae: 4.2417 - rmse: 5.4632 - val_loss: 38.5270 - val_mae: 4.6376 - val_rmse: 6.2070
# Epoch 21/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 72ms/step - loss: 29.3770 - mae: 4.2055 - rmse: 5.4201 - val_loss: 38.6826 - val_mae: 4.7173 - val_rmse: 6.2195
# Epoch 22/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 71ms/step - loss: 28.9259 - mae: 4.1530 - rmse: 5.3783 - val_loss: 38.5328 - val_mae: 4.7101 - val_rmse: 6.2075
# Epoch 23/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 74ms/step - loss: 28.4756 - mae: 4.1413 - rmse: 5.3363 - val_loss: 38.8740 - val_mae: 4.7580 - val_rmse: 6.2349
# Epoch 24/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 75ms/step - loss: 28.0413 - mae: 4.0768 - rmse: 5.2954 - val_loss: 38.4331 - val_mae: 4.6896 - val_rmse: 6.1994
# Epoch 25/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 70ms/step - loss: 27.5593 - mae: 4.0511 - rmse: 5.2497 - val_loss: 38.6240 - val_mae: 4.7040 - val_rmse: 6.2148
# Epoch 26/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 72ms/step - loss: 27.2088 - mae: 4.0080 - rmse: 5.2162 - val_loss: 38.9321 - val_mae: 4.7499 - val_rmse: 6.2396
# Epoch 27/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 72ms/step - loss: 26.8959 - mae: 3.9897 - rmse: 5.1861 - val_loss: 39.5055 - val_mae: 4.8387 - val_rmse: 6.2853
# Epoch 28/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 73ms/step - loss: 26.5256 - mae: 3.9500 - rmse: 5.1503 - val_loss: 39.0253 - val_mae: 4.6887 - val_rmse: 6.2470
# Epoch 29/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 73ms/step - loss: 25.9540 - mae: 3.9218 - rmse: 5.0945 - val_loss: 39.0770 - val_mae: 4.7114 - val_rmse: 6.2512
# Epoch 30/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 69ms/step - loss: 25.9951 - mae: 3.9068 - rmse: 5.0985 - val_loss: 39.3080 - val_mae: 4.7647 - val_rmse: 6.2696
# Epoch 31/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 80ms/step - loss: 25.8506 - mae: 3.8991 - rmse: 5.0843 - val_loss: 40.0977 - val_mae: 4.8117 - val_rmse: 6.3323
# Epoch 32/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 73ms/step - loss: 25.2127 - mae: 3.8431 - rmse: 5.0212 - val_loss: 39.7959 - val_mae: 4.7068 - val_rmse: 6.3084
# Epoch 33/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 72ms/step - loss: 25.2347 - mae: 3.8306 - rmse: 5.0234 - val_loss: 40.0522 - val_mae: 4.8294 - val_rmse: 6.3287
# Epoch 34/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 76ms/step - loss: 24.5851 - mae: 3.7956 - rmse: 4.9583 - val_loss: 39.3455 - val_mae: 4.6871 - val_rmse: 6.2726
# Epoch 35/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 76ms/step - loss: 24.0100 - mae: 3.7457 - rmse: 4.9000 - val_loss: 39.4242 - val_mae: 4.7076 - val_rmse: 6.2789
# Epoch 36/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 78ms/step - loss: 24.3206 - mae: 3.7797 - rmse: 4.9316 - val_loss: 39.4402 - val_mae: 4.6619 - val_rmse: 6.2801
# Epoch 37/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 73ms/step - loss: 24.2178 - mae: 3.7509 - rmse: 4.9212 - val_loss: 39.3568 - val_mae: 4.6473 - val_rmse: 6.2735
# Epoch 38/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 73ms/step - loss: 23.3569 - mae: 3.6673 - rmse: 4.8329 - val_loss: 39.3282 - val_mae: 4.6913 - val_rmse: 6.2712
# Epoch 39/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 77ms/step - loss: 23.0886 - mae: 3.6528 - rmse: 4.8051 - val_loss: 39.8913 - val_mae: 4.7367 - val_rmse: 6.3160
# Epoch 40/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 83ms/step - loss: 22.9184 - mae: 3.6458 - rmse: 4.7873 - val_loss: 39.5804 - val_mae: 4.7364 - val_rmse: 6.2913
# Epoch 41/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 76ms/step - loss: 22.8724 - mae: 3.6136 - rmse: 4.7825 - val_loss: 39.6225 - val_mae: 4.6843 - val_rmse: 6.2946
# Epoch 42/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 77ms/step - loss: 22.1717 - mae: 3.5743 - rmse: 4.7087 - val_loss: 39.4400 - val_mae: 4.6498 - val_rmse: 6.2801
# Epoch 43/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 86ms/step - loss: 21.6895 - mae: 3.5339 - rmse: 4.6572 - val_loss: 39.8461 - val_mae: 4.7177 - val_rmse: 6.3124
# Epoch 44/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 81ms/step - loss: 21.2724 - mae: 3.4864 - rmse: 4.6122 - val_loss: 40.0803 - val_mae: 4.6952 - val_rmse: 6.3309
# Epoch 45/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 76ms/step - loss: 21.2554 - mae: 3.4854 - rmse: 4.6104 - val_loss: 39.8652 - val_mae: 4.6986 - val_rmse: 6.3139
# Epoch 46/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 86ms/step - loss: 21.1437 - mae: 3.4843 - rmse: 4.5982 - val_loss: 41.0032 - val_mae: 4.8464 - val_rmse: 6.4034
# Epoch 47/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 84ms/step - loss: 21.0852 - mae: 3.4731 - rmse: 4.5919 - val_loss: 40.9479 - val_mae: 4.8168 - val_rmse: 6.3991
# Epoch 48/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 76ms/step - loss: 20.8902 - mae: 3.4450 - rmse: 4.5706 - val_loss: 40.7043 - val_mae: 4.7780 - val_rmse: 6.3800
# Epoch 49/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 77ms/step - loss: 20.6061 - mae: 3.4440 - rmse: 4.5394 - val_loss: 40.4405 - val_mae: 4.7017 - val_rmse: 6.3593
# Epoch 50/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 74ms/step - loss: 20.2890 - mae: 3.4188 - rmse: 4.5043 - val_loss: 40.7374 - val_mae: 4.7277 - val_rmse: 6.3826
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 38.1633 - mae: 4.7105 - rmse: 6.1776
# -> MLP-S-2: Optimal Depth Test (3x64): Test RMSE=6.1776, Test R2=0.2974

# %% [markdown]
# By increasing the depth layers, the resulting model underperforms the previous baseline model. This suggests we take a look on the effect of increasing width as well.

# %% [markdown]
# ### MLP-S-3: Optimal Width Test (2 Layers, 128 Neurons)
#
# Increases layer width (capacity) to 128 while fixing depth to 2. This helps disentangle the impact of parameter count from the impact of network depth.

# %%
model_s3 = create_sequential_model(n_features=N_FEATURES, layers=[128, 64], optimizer=Adam(learning_rate=0.001))
history_s3 = run_dl_experiment(model_s3, "MLP-S-3: Optimal Width Test (128, 64)", X_train_processed, Y_train_array, X_val_processed, Y_val_array)
# Out:
# Epoch 1/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 61ms/step - loss: 204.7282 - mae: 12.1732 - rmse: 14.3083 - val_loss: 125.3746 - val_mae: 8.8803 - val_rmse: 11.1971
# Epoch 2/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 65ms/step - loss: 72.0418 - mae: 6.5287 - rmse: 8.4877 - val_loss: 58.7814 - val_mae: 6.0156 - val_rmse: 7.6669
# Epoch 3/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 62ms/step - loss: 48.9957 - mae: 5.5476 - rmse: 6.9997 - val_loss: 50.1890 - val_mae: 5.4424 - val_rmse: 7.0844
# Epoch 4/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 64ms/step - loss: 44.1357 - mae: 5.2645 - rmse: 6.6435 - val_loss: 47.6043 - val_mae: 5.3908 - val_rmse: 6.8996
# Epoch 5/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 61ms/step - loss: 41.9616 - mae: 5.1562 - rmse: 6.4778 - val_loss: 45.5936 - val_mae: 5.2792 - val_rmse: 6.7523
# Epoch 6/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 61ms/step - loss: 40.3254 - mae: 5.0384 - rmse: 6.3502 - val_loss: 44.3202 - val_mae: 5.1601 - val_rmse: 6.6573
# Epoch 7/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 61ms/step - loss: 39.3807 - mae: 4.9585 - rmse: 6.2754 - val_loss: 43.7386 - val_mae: 5.1225 - val_rmse: 6.6135
# Epoch 8/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 60ms/step - loss: 38.6754 - mae: 4.9168 - rmse: 6.2190 - val_loss: 42.7519 - val_mae: 4.9712 - val_rmse: 6.5385
# Epoch 9/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 59ms/step - loss: 37.9983 - mae: 4.8512 - rmse: 6.1643 - val_loss: 42.4165 - val_mae: 5.0406 - val_rmse: 6.5128
# Epoch 10/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 60ms/step - loss: 37.4162 - mae: 4.8132 - rmse: 6.1169 - val_loss: 41.7357 - val_mae: 4.9568 - val_rmse: 6.4603
# Epoch 11/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 65ms/step - loss: 36.9425 - mae: 4.7608 - rmse: 6.0780 - val_loss: 41.9924 - val_mae: 5.0198 - val_rmse: 6.4802
# Epoch 12/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 65ms/step - loss: 36.4974 - mae: 4.7555 - rmse: 6.0413 - val_loss: 41.0956 - val_mae: 4.9199 - val_rmse: 6.4106
# Epoch 13/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 62ms/step - loss: 35.9820 - mae: 4.6909 - rmse: 5.9985 - val_loss: 40.7225 - val_mae: 4.8992 - val_rmse: 6.3814
# Epoch 14/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 61ms/step - loss: 35.5169 - mae: 4.6713 - rmse: 5.9596 - val_loss: 40.9992 - val_mae: 4.9425 - val_rmse: 6.4031
# Epoch 15/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 60ms/step - loss: 35.1321 - mae: 4.6478 - rmse: 5.9272 - val_loss: 40.3194 - val_mae: 4.8597 - val_rmse: 6.3498
# Epoch 16/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 59ms/step - loss: 34.4972 - mae: 4.5587 - rmse: 5.8734 - val_loss: 40.1540 - val_mae: 4.8879 - val_rmse: 6.3367
# Epoch 17/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 62ms/step - loss: 34.0930 - mae: 4.5860 - rmse: 5.8389 - val_loss: 39.6032 - val_mae: 4.8196 - val_rmse: 6.2931
# Epoch 18/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 64ms/step - loss: 33.7327 - mae: 4.5275 - rmse: 5.8080 - val_loss: 40.0251 - val_mae: 4.9061 - val_rmse: 6.3265
# Epoch 19/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - loss: 33.2757 - mae: 4.5231 - rmse: 5.7685 - val_loss: 39.2968 - val_mae: 4.7911 - val_rmse: 6.2687
# Epoch 20/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 56ms/step - loss: 32.6979 - mae: 4.4779 - rmse: 5.7182 - val_loss: 39.2143 - val_mae: 4.8175 - val_rmse: 6.2621
# Epoch 21/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 60ms/step - loss: 32.0984 - mae: 4.4191 - rmse: 5.6655 - val_loss: 39.1639 - val_mae: 4.8074 - val_rmse: 6.2581
# Epoch 22/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 62ms/step - loss: 31.6003 - mae: 4.3930 - rmse: 5.6214 - val_loss: 38.8702 - val_mae: 4.7804 - val_rmse: 6.2346
# Epoch 23/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 59ms/step - loss: 31.1645 - mae: 4.3501 - rmse: 5.5825 - val_loss: 38.6610 - val_mae: 4.7381 - val_rmse: 6.2178
# Epoch 24/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - loss: 30.7907 - mae: 4.3013 - rmse: 5.5489 - val_loss: 38.5615 - val_mae: 4.7327 - val_rmse: 6.2098
# Epoch 25/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 61ms/step - loss: 30.5049 - mae: 4.3175 - rmse: 5.5231 - val_loss: 38.4307 - val_mae: 4.7121 - val_rmse: 6.1993
# Epoch 26/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 61ms/step - loss: 30.1067 - mae: 4.2375 - rmse: 5.4870 - val_loss: 38.5230 - val_mae: 4.7680 - val_rmse: 6.2067
# Epoch 27/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 64ms/step - loss: 29.5920 - mae: 4.2462 - rmse: 5.4399 - val_loss: 38.2278 - val_mae: 4.6818 - val_rmse: 6.1829
# Epoch 28/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 61ms/step - loss: 29.3015 - mae: 4.1881 - rmse: 5.4131 - val_loss: 38.7807 - val_mae: 4.7779 - val_rmse: 6.2274
# Epoch 29/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 62ms/step - loss: 29.1990 - mae: 4.1783 - rmse: 5.4036 - val_loss: 38.3441 - val_mae: 4.6463 - val_rmse: 6.1923
# Epoch 30/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 72ms/step - loss: 28.4584 - mae: 4.1234 - rmse: 5.3346 - val_loss: 38.7170 - val_mae: 4.7562 - val_rmse: 6.2223
# Epoch 31/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 64ms/step - loss: 28.2759 - mae: 4.1126 - rmse: 5.3175 - val_loss: 38.2606 - val_mae: 4.7022 - val_rmse: 6.1855
# Epoch 32/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 64ms/step - loss: 27.7418 - mae: 4.0658 - rmse: 5.2670 - val_loss: 38.0504 - val_mae: 4.6492 - val_rmse: 6.1685
# Epoch 33/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 59ms/step - loss: 27.9619 - mae: 4.0736 - rmse: 5.2879 - val_loss: 38.8331 - val_mae: 4.7696 - val_rmse: 6.2316
# Epoch 34/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 62ms/step - loss: 27.2240 - mae: 4.0053 - rmse: 5.2177 - val_loss: 38.2216 - val_mae: 4.6716 - val_rmse: 6.1824
# Epoch 35/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 61ms/step - loss: 26.8576 - mae: 3.9792 - rmse: 5.1824 - val_loss: 38.1707 - val_mae: 4.6495 - val_rmse: 6.1782
# Epoch 36/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 64ms/step - loss: 26.6448 - mae: 3.9616 - rmse: 5.1619 - val_loss: 38.3786 - val_mae: 4.6393 - val_rmse: 6.1950
# Epoch 37/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 66ms/step - loss: 26.4724 - mae: 3.9419 - rmse: 5.1451 - val_loss: 38.4497 - val_mae: 4.6623 - val_rmse: 6.2008
# Epoch 38/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 74ms/step - loss: 26.0193 - mae: 3.9173 - rmse: 5.1009 - val_loss: 38.4541 - val_mae: 4.6545 - val_rmse: 6.2011
# Epoch 39/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 66ms/step - loss: 26.1693 - mae: 3.9045 - rmse: 5.1156 - val_loss: 38.7792 - val_mae: 4.6641 - val_rmse: 6.2273
# Epoch 40/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 61ms/step - loss: 25.5379 - mae: 3.8476 - rmse: 5.0535 - val_loss: 39.7021 - val_mae: 4.8071 - val_rmse: 6.3010
# Epoch 41/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 60ms/step - loss: 25.4539 - mae: 3.8548 - rmse: 5.0452 - val_loss: 38.7074 - val_mae: 4.6623 - val_rmse: 6.2215
# Epoch 42/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 61ms/step - loss: 24.9947 - mae: 3.8134 - rmse: 4.9995 - val_loss: 39.1864 - val_mae: 4.7245 - val_rmse: 6.2599
# Epoch 43/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 64ms/step - loss: 24.7336 - mae: 3.7952 - rmse: 4.9733 - val_loss: 38.9457 - val_mae: 4.6639 - val_rmse: 6.2406
# Epoch 44/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 62ms/step - loss: 24.5698 - mae: 3.7757 - rmse: 4.9568 - val_loss: 39.3877 - val_mae: 4.7024 - val_rmse: 6.2760
# Epoch 45/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 61ms/step - loss: 24.2884 - mae: 3.7486 - rmse: 4.9283 - val_loss: 39.3293 - val_mae: 4.7053 - val_rmse: 6.2713
# Epoch 46/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 64ms/step - loss: 24.3411 - mae: 3.7725 - rmse: 4.9337 - val_loss: 39.4593 - val_mae: 4.6899 - val_rmse: 6.2817
# Epoch 47/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 63ms/step - loss: 24.2482 - mae: 3.7558 - rmse: 4.9242 - val_loss: 39.6320 - val_mae: 4.7073 - val_rmse: 6.2954
# Epoch 48/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 61ms/step - loss: 23.6414 - mae: 3.6881 - rmse: 4.8622 - val_loss: 39.6094 - val_mae: 4.7025 - val_rmse: 6.2936
# Epoch 49/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 61ms/step - loss: 23.5748 - mae: 3.6942 - rmse: 4.8554 - val_loss: 39.6642 - val_mae: 4.7214 - val_rmse: 6.2980
# Epoch 50/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 62ms/step - loss: 23.2174 - mae: 3.6438 - rmse: 4.8184 - val_loss: 39.9485 - val_mae: 4.7267 - val_rmse: 6.3205
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 37.6813 - mae: 4.8877 - rmse: 6.1385
# -> MLP-S-3: Optimal Width Test (128, 64): Test RMSE=6.1385, Test R2=0.3063

# %% [markdown]
# The results from above experiments shows even a better performance. We managed to get RMSE down to appr. 6.13 and upped R2 to appr. 0.30 which are slightly better metrics compared to the previous MLP experiments.

# %% [markdown]
# ### MLP-S-4: Optimizer Comparison (RMSprop)
#
# In this experiment, let's compare the widely used Adam optimizer against RMSprop. This experiment is built from the previous experiment of layer width test. This is a requirement for exploring different optimization strategies, testing for faster or more stable convergence.

# %%
model_s4 = create_sequential_model(N_FEATURES, layers=[128, 64], optimizer=tf.keras.optimizers.RMSprop(learning_rate=0.001))
history_s4 = run_dl_experiment(model_s4, "MLP-S-4: Optimizer Comparison (RMSprop)", X_train_processed, Y_train_array, X_val_processed, Y_val_array)
# Out:
# Epoch 1/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - loss: 163.8586 - mae: 10.5030 - rmse: 12.8007 - val_loss: 81.2601 - val_mae: 6.6860 - val_rmse: 9.0144
# Epoch 2/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 45ms/step - loss: 58.8803 - mae: 5.8990 - rmse: 7.6733 - val_loss: 54.1167 - val_mae: 5.5969 - val_rmse: 7.3564
# Epoch 3/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 45ms/step - loss: 47.2992 - mae: 5.4453 - rmse: 6.8774 - val_loss: 48.8741 - val_mae: 5.3432 - val_rmse: 6.9910
# Epoch 4/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step - loss: 43.1711 - mae: 5.1946 - rmse: 6.5705 - val_loss: 46.6509 - val_mae: 5.3397 - val_rmse: 6.8301
# Epoch 5/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step - loss: 41.1914 - mae: 5.0767 - rmse: 6.4181 - val_loss: 44.8165 - val_mae: 5.1951 - val_rmse: 6.6945
# Epoch 6/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step - loss: 39.7545 - mae: 4.9609 - rmse: 6.3051 - val_loss: 44.0380 - val_mae: 5.1750 - val_rmse: 6.6361
# Epoch 7/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - loss: 38.7363 - mae: 4.8891 - rmse: 6.2238 - val_loss: 42.7270 - val_mae: 5.0247 - val_rmse: 6.5366
# Epoch 8/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - loss: 38.0496 - mae: 4.8444 - rmse: 6.1684 - val_loss: 42.0788 - val_mae: 4.9836 - val_rmse: 6.4868
# Epoch 9/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 45ms/step - loss: 37.4707 - mae: 4.7978 - rmse: 6.1213 - val_loss: 41.3008 - val_mae: 4.9179 - val_rmse: 6.4266
# Epoch 10/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step - loss: 36.7479 - mae: 4.7375 - rmse: 6.0620 - val_loss: 40.9270 - val_mae: 4.9002 - val_rmse: 6.3974
# Epoch 11/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step - loss: 36.0990 - mae: 4.6800 - rmse: 6.0082 - val_loss: 40.1546 - val_mae: 4.8090 - val_rmse: 6.3368
# Epoch 12/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - loss: 35.4674 - mae: 4.6353 - rmse: 5.9555 - val_loss: 39.8485 - val_mae: 4.7886 - val_rmse: 6.3126
# Epoch 13/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - loss: 34.9790 - mae: 4.5891 - rmse: 5.9143 - val_loss: 39.4763 - val_mae: 4.7924 - val_rmse: 6.2830
# Epoch 14/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - loss: 34.2203 - mae: 4.5545 - rmse: 5.8498 - val_loss: 39.7809 - val_mae: 4.7212 - val_rmse: 6.3072
# Epoch 15/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - loss: 33.8691 - mae: 4.5208 - rmse: 5.8197 - val_loss: 38.8968 - val_mae: 4.7732 - val_rmse: 6.2367
# Epoch 16/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - loss: 33.2169 - mae: 4.4860 - rmse: 5.7634 - val_loss: 38.7015 - val_mae: 4.7116 - val_rmse: 6.2211
# Epoch 17/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step - loss: 32.9491 - mae: 4.4268 - rmse: 5.7401 - val_loss: 38.5593 - val_mae: 4.7812 - val_rmse: 6.2096
# Epoch 18/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step - loss: 32.3278 - mae: 4.4102 - rmse: 5.6858 - val_loss: 38.3764 - val_mae: 4.7393 - val_rmse: 6.1949
# Epoch 19/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 47ms/step - loss: 31.9106 - mae: 4.3670 - rmse: 5.6489 - val_loss: 38.4050 - val_mae: 4.7066 - val_rmse: 6.1972
# Epoch 20/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - loss: 31.4913 - mae: 4.3449 - rmse: 5.6117 - val_loss: 38.1860 - val_mae: 4.6749 - val_rmse: 6.1795
# Epoch 21/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 45ms/step - loss: 31.1140 - mae: 4.3025 - rmse: 5.5780 - val_loss: 37.9903 - val_mae: 4.7450 - val_rmse: 6.1636
# Epoch 22/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - loss: 30.8693 - mae: 4.2997 - rmse: 5.5560 - val_loss: 38.0999 - val_mae: 4.6869 - val_rmse: 6.1725
# Epoch 23/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - loss: 30.5208 - mae: 4.2661 - rmse: 5.5246 - val_loss: 37.9479 - val_mae: 4.6872 - val_rmse: 6.1602
# Epoch 24/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - loss: 30.0401 - mae: 4.2159 - rmse: 5.4809 - val_loss: 38.3139 - val_mae: 4.7666 - val_rmse: 6.1898
# Epoch 25/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 47ms/step - loss: 29.5499 - mae: 4.1895 - rmse: 5.4360 - val_loss: 37.8861 - val_mae: 4.6528 - val_rmse: 6.1552
# Epoch 26/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 45ms/step - loss: 29.4470 - mae: 4.1805 - rmse: 5.4265 - val_loss: 37.9867 - val_mae: 4.6713 - val_rmse: 6.1633
# Epoch 27/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 45ms/step - loss: 28.9477 - mae: 4.1298 - rmse: 5.3803 - val_loss: 38.7523 - val_mae: 4.8310 - val_rmse: 6.2251
# Epoch 28/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - loss: 28.8086 - mae: 4.1322 - rmse: 5.3674 - val_loss: 37.9282 - val_mae: 4.6680 - val_rmse: 6.1586
# Epoch 29/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - loss: 28.4412 - mae: 4.0921 - rmse: 5.3330 - val_loss: 38.0766 - val_mae: 4.6816 - val_rmse: 6.1706
# Epoch 30/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - loss: 28.0293 - mae: 4.0523 - rmse: 5.2943 - val_loss: 39.0326 - val_mae: 4.8291 - val_rmse: 6.2476
# Epoch 31/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - loss: 27.7776 - mae: 4.0404 - rmse: 5.2704 - val_loss: 38.1136 - val_mae: 4.6011 - val_rmse: 6.1736
# Epoch 32/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - loss: 27.5963 - mae: 4.0240 - rmse: 5.2532 - val_loss: 38.5155 - val_mae: 4.7378 - val_rmse: 6.2061
# Epoch 33/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 47ms/step - loss: 27.2812 - mae: 3.9873 - rmse: 5.2231 - val_loss: 38.9056 - val_mae: 4.7779 - val_rmse: 6.2374
# Epoch 34/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - loss: 27.0593 - mae: 3.9875 - rmse: 5.2019 - val_loss: 38.4594 - val_mae: 4.6193 - val_rmse: 6.2016
# Epoch 35/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - loss: 26.8498 - mae: 3.9562 - rmse: 5.1817 - val_loss: 38.5409 - val_mae: 4.6986 - val_rmse: 6.2081
# Epoch 36/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - loss: 26.5351 - mae: 3.9402 - rmse: 5.1512 - val_loss: 38.6537 - val_mae: 4.7038 - val_rmse: 6.2172
# Epoch 37/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - loss: 26.4509 - mae: 3.9176 - rmse: 5.1430 - val_loss: 38.2382 - val_mae: 4.6142 - val_rmse: 6.1837
# Epoch 38/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - loss: 26.1782 - mae: 3.9165 - rmse: 5.1165 - val_loss: 38.6533 - val_mae: 4.6688 - val_rmse: 6.2172
# Epoch 39/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 45ms/step - loss: 25.8852 - mae: 3.8739 - rmse: 5.0877 - val_loss: 38.7400 - val_mae: 4.5941 - val_rmse: 6.2241
# Epoch 40/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - loss: 25.7227 - mae: 3.8593 - rmse: 5.0718 - val_loss: 38.6923 - val_mae: 4.6554 - val_rmse: 6.2203
# Epoch 41/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - loss: 25.4487 - mae: 3.8280 - rmse: 5.0447 - val_loss: 39.8123 - val_mae: 4.8290 - val_rmse: 6.3097
# Epoch 42/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - loss: 25.2198 - mae: 3.8197 - rmse: 5.0219 - val_loss: 39.4360 - val_mae: 4.7649 - val_rmse: 6.2798
# Epoch 43/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 45ms/step - loss: 24.9881 - mae: 3.8020 - rmse: 4.9988 - val_loss: 39.6800 - val_mae: 4.6460 - val_rmse: 6.2992
# Epoch 44/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 47ms/step - loss: 24.8314 - mae: 3.7758 - rmse: 4.9831 - val_loss: 39.1208 - val_mae: 4.6845 - val_rmse: 6.2547
# Epoch 45/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - loss: 24.7433 - mae: 3.7805 - rmse: 4.9743 - val_loss: 38.8288 - val_mae: 4.6294 - val_rmse: 6.2313
# Epoch 46/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - loss: 24.5669 - mae: 3.7527 - rmse: 4.9565 - val_loss: 39.7129 - val_mae: 4.7781 - val_rmse: 6.3018
# Epoch 47/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - loss: 24.4149 - mae: 3.7507 - rmse: 4.9411 - val_loss: 40.2458 - val_mae: 4.8240 - val_rmse: 6.3440
# Epoch 48/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 47ms/step - loss: 24.1796 - mae: 3.7367 - rmse: 4.9173 - val_loss: 39.2549 - val_mae: 4.6707 - val_rmse: 6.2654
# Epoch 49/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - loss: 24.0590 - mae: 3.7285 - rmse: 4.9050 - val_loss: 39.3633 - val_mae: 4.7179 - val_rmse: 6.2740
# Epoch 50/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - loss: 23.7042 - mae: 3.7053 - rmse: 4.8687 - val_loss: 39.5137 - val_mae: 4.6845 - val_rmse: 6.2860
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 37.3744 - mae: 4.7926 - rmse: 6.1135
# -> MLP-S-4: Optimizer Comparison (RMSprop): Test RMSE=6.1135, Test R2=0.3119

# %% [markdown]
# Now we see that the RMSE and R2 almost didn't improve much (slightly improved). In the next experiments we can try a different activation function as well using the Adam optimizer since it is not outperformed.

# %% [markdown]
# ### MLP-S-5: Activation Function Comparison (LeakyReLU)
#
# Replaces the standard ReLU with LeakyReLU. LeakyReLU addresses the "dying ReLU" problem by allowing a small, non-zero gradient when the unit is not active, potentially improving training stability. In this experiment, we keep the layers width to [128, 64] as it's performing well.

# %%
model_s5 = create_sequential_model(N_FEATURES, layers=[128, 64], activation=tf.keras.layers.LeakyReLU(alpha=0.01), optimizer=Adam(learning_rate=0.001))
history_s5 = run_dl_experiment(model_s5, "MLP-S-5: Activation Comparison (LeakyReLU)", X_train_processed, Y_train_array, X_val_processed, Y_val_array)
# Out:
# Epoch 1/50
#  1/37 ━━━━━━━━━━━━━━━━━━━━ 4s 120ms/step - loss: 234.6793 - mae: 13.5945 - rmse: 15.3192
# /home/degide/.mlvenv/lib/python3.13/site-packages/keras/src/layers/activations/leaky_relu.py:41: UserWarning: Argument `alpha` is deprecated. Use `negative_slope` instead.
#   warnings.warn(
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 66ms/step - loss: 211.1741 - mae: 12.4647 - rmse: 14.5318 - val_loss: 136.7682 - val_mae: 9.3629 - val_rmse: 11.6948
# Epoch 2/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 63ms/step - loss: 80.3138 - mae: 6.8712 - rmse: 8.9618 - val_loss: 61.4552 - val_mae: 6.1226 - val_rmse: 7.8393
# Epoch 3/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 67ms/step - loss: 49.7570 - mae: 5.5977 - rmse: 7.0539 - val_loss: 51.0504 - val_mae: 5.4513 - val_rmse: 7.1450
# Epoch 4/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 62ms/step - loss: 44.2683 - mae: 5.2806 - rmse: 6.6534 - val_loss: 48.3600 - val_mae: 5.3872 - val_rmse: 6.9541
# Epoch 5/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 68ms/step - loss: 41.7238 - mae: 5.1462 - rmse: 6.4594 - val_loss: 45.6933 - val_mae: 5.1706 - val_rmse: 6.7597
# Epoch 6/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 64ms/step - loss: 40.3604 - mae: 5.0082 - rmse: 6.3530 - val_loss: 44.4591 - val_mae: 5.0967 - val_rmse: 6.6678
# Epoch 7/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 63ms/step - loss: 39.1545 - mae: 4.9543 - rmse: 6.2574 - val_loss: 43.5728 - val_mae: 5.0714 - val_rmse: 6.6010
# Epoch 8/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 62ms/step - loss: 38.2509 - mae: 4.8851 - rmse: 6.1847 - val_loss: 42.6769 - val_mae: 4.9648 - val_rmse: 6.5328
# Epoch 9/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 64ms/step - loss: 37.7153 - mae: 4.8266 - rmse: 6.1413 - val_loss: 42.2086 - val_mae: 4.9867 - val_rmse: 6.4968
# Epoch 10/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 61ms/step - loss: 37.0606 - mae: 4.7545 - rmse: 6.0877 - val_loss: 42.2008 - val_mae: 5.0427 - val_rmse: 6.4962
# Epoch 11/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 64ms/step - loss: 36.5526 - mae: 4.7349 - rmse: 6.0459 - val_loss: 42.3166 - val_mae: 5.0558 - val_rmse: 6.5051
# Epoch 12/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 68ms/step - loss: 36.0165 - mae: 4.7180 - rmse: 6.0014 - val_loss: 40.8466 - val_mae: 4.9098 - val_rmse: 6.3911
# Epoch 13/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 73ms/step - loss: 35.2780 - mae: 4.6399 - rmse: 5.9395 - val_loss: 40.2532 - val_mae: 4.7785 - val_rmse: 6.3445
# Epoch 14/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 69ms/step - loss: 34.7872 - mae: 4.6002 - rmse: 5.8981 - val_loss: 39.7970 - val_mae: 4.8416 - val_rmse: 6.3085
# Epoch 15/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 69ms/step - loss: 34.1178 - mae: 4.5585 - rmse: 5.8410 - val_loss: 39.3898 - val_mae: 4.7449 - val_rmse: 6.2761
# Epoch 16/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 62ms/step - loss: 33.7252 - mae: 4.5162 - rmse: 5.8073 - val_loss: 38.9619 - val_mae: 4.7745 - val_rmse: 6.2419
# Epoch 17/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 56ms/step - loss: 33.0605 - mae: 4.4780 - rmse: 5.7498 - val_loss: 38.6134 - val_mae: 4.7654 - val_rmse: 6.2140
# Epoch 18/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 61ms/step - loss: 32.4916 - mae: 4.4282 - rmse: 5.7001 - val_loss: 38.1344 - val_mae: 4.7053 - val_rmse: 6.1753
# Epoch 19/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 66ms/step - loss: 32.1784 - mae: 4.3826 - rmse: 5.6726 - val_loss: 38.5433 - val_mae: 4.8144 - val_rmse: 6.2083
# Epoch 20/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 63ms/step - loss: 31.6646 - mae: 4.3858 - rmse: 5.6271 - val_loss: 37.6788 - val_mae: 4.6646 - val_rmse: 6.1383
# Epoch 21/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 59ms/step - loss: 31.1348 - mae: 4.3149 - rmse: 5.5799 - val_loss: 37.4061 - val_mae: 4.6470 - val_rmse: 6.1161
# Epoch 22/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 55ms/step - loss: 30.6798 - mae: 4.2817 - rmse: 5.5389 - val_loss: 37.4444 - val_mae: 4.6126 - val_rmse: 6.1192
# Epoch 23/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 56ms/step - loss: 30.5988 - mae: 4.2652 - rmse: 5.5316 - val_loss: 37.1574 - val_mae: 4.6279 - val_rmse: 6.0957
# Epoch 24/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - loss: 30.0718 - mae: 4.2336 - rmse: 5.4838 - val_loss: 37.4672 - val_mae: 4.7100 - val_rmse: 6.1210
# Epoch 25/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 67ms/step - loss: 29.5821 - mae: 4.2042 - rmse: 5.4389 - val_loss: 37.2797 - val_mae: 4.7093 - val_rmse: 6.1057
# Epoch 26/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 69ms/step - loss: 29.5772 - mae: 4.1789 - rmse: 5.4385 - val_loss: 36.9049 - val_mae: 4.6106 - val_rmse: 6.0749
# Epoch 27/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 65ms/step - loss: 29.1464 - mae: 4.1665 - rmse: 5.3987 - val_loss: 37.3911 - val_mae: 4.7107 - val_rmse: 6.1148
# Epoch 28/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 68ms/step - loss: 28.7640 - mae: 4.1158 - rmse: 5.3632 - val_loss: 37.3145 - val_mae: 4.6983 - val_rmse: 6.1086
# Epoch 29/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 61ms/step - loss: 28.4916 - mae: 4.1052 - rmse: 5.3378 - val_loss: 37.6115 - val_mae: 4.7353 - val_rmse: 6.1328
# Epoch 30/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 66ms/step - loss: 28.2074 - mae: 4.1092 - rmse: 5.3111 - val_loss: 37.0104 - val_mae: 4.6165 - val_rmse: 6.0836
# Epoch 31/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 69ms/step - loss: 27.8885 - mae: 4.0513 - rmse: 5.2810 - val_loss: 37.2324 - val_mae: 4.6528 - val_rmse: 6.1018
# Epoch 32/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 72ms/step - loss: 27.6767 - mae: 4.0373 - rmse: 5.2609 - val_loss: 37.0654 - val_mae: 4.6247 - val_rmse: 6.0881
# Epoch 33/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 71ms/step - loss: 27.4519 - mae: 4.0172 - rmse: 5.2395 - val_loss: 37.3386 - val_mae: 4.6715 - val_rmse: 6.1105
# Epoch 34/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 71ms/step - loss: 27.1541 - mae: 4.0130 - rmse: 5.2110 - val_loss: 37.1435 - val_mae: 4.6041 - val_rmse: 6.0945
# Epoch 35/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 71ms/step - loss: 27.0304 - mae: 3.9989 - rmse: 5.1991 - val_loss: 37.5541 - val_mae: 4.6343 - val_rmse: 6.1281
# Epoch 36/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 74ms/step - loss: 26.7992 - mae: 3.9673 - rmse: 5.1768 - val_loss: 37.5903 - val_mae: 4.6728 - val_rmse: 6.1311
# Epoch 37/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 68ms/step - loss: 26.3777 - mae: 3.9395 - rmse: 5.1359 - val_loss: 37.4787 - val_mae: 4.6279 - val_rmse: 6.1220
# Epoch 38/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 71ms/step - loss: 26.3570 - mae: 3.9346 - rmse: 5.1339 - val_loss: 37.4955 - val_mae: 4.6354 - val_rmse: 6.1234
# Epoch 39/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 66ms/step - loss: 26.0689 - mae: 3.9049 - rmse: 5.1058 - val_loss: 37.5406 - val_mae: 4.6240 - val_rmse: 6.1270
# Epoch 40/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 75ms/step - loss: 25.7163 - mae: 3.8871 - rmse: 5.0711 - val_loss: 38.3636 - val_mae: 4.7584 - val_rmse: 6.1938
# Epoch 41/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 73ms/step - loss: 25.7932 - mae: 3.8737 - rmse: 5.0787 - val_loss: 38.7799 - val_mae: 4.7886 - val_rmse: 6.2274
# Epoch 42/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 70ms/step - loss: 25.8953 - mae: 3.9003 - rmse: 5.0887 - val_loss: 38.2569 - val_mae: 4.7057 - val_rmse: 6.1852
# Epoch 43/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 77ms/step - loss: 25.4416 - mae: 3.8611 - rmse: 5.0440 - val_loss: 37.8339 - val_mae: 4.6357 - val_rmse: 6.1509
# Epoch 44/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 76ms/step - loss: 25.1129 - mae: 3.8403 - rmse: 5.0113 - val_loss: 37.9108 - val_mae: 4.6321 - val_rmse: 6.1572
# Epoch 45/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 71ms/step - loss: 24.8649 - mae: 3.8061 - rmse: 4.9865 - val_loss: 38.2602 - val_mae: 4.6684 - val_rmse: 6.1855
# Epoch 46/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 68ms/step - loss: 24.6127 - mae: 3.8007 - rmse: 4.9611 - val_loss: 38.5934 - val_mae: 4.7284 - val_rmse: 6.2124
# Epoch 47/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 68ms/step - loss: 24.5434 - mae: 3.7829 - rmse: 4.9541 - val_loss: 38.3323 - val_mae: 4.6905 - val_rmse: 6.1913
# Epoch 48/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 67ms/step - loss: 24.4650 - mae: 3.7898 - rmse: 4.9462 - val_loss: 38.2474 - val_mae: 4.6368 - val_rmse: 6.1844
# Epoch 49/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 55ms/step - loss: 24.2103 - mae: 3.7571 - rmse: 4.9204 - val_loss: 38.3797 - val_mae: 4.6685 - val_rmse: 6.1951
# Epoch 50/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - loss: 23.9077 - mae: 3.7477 - rmse: 4.8896 - val_loss: 38.6982 - val_mae: 4.7177 - val_rmse: 6.2208
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 37.2343 - mae: 4.7365 - rmse: 6.1020
# -> MLP-S-5: Activation Comparison (LeakyReLU): Test RMSE=6.1020, Test R2=0.3145

# %% [markdown]
# The results shows an improvement. The RMSE is down to 6.10 and R2 is up to 0.31. Let's combine this experiment with early stopping in the next experiment.

# %% [markdown]
# ### MLP-S-6: Early Stopping Implementation
#
# Early Stopping is a crucial regularization technique for deep learning. It stops training when the validation loss fails to improve for a set number of epochs (patience), preventing overfitting and saving computational resources.

# %%
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
model_s6 = create_sequential_model(N_FEATURES, layers=[128, 64], activation=tf.keras.layers.LeakyReLU(alpha=0.01), optimizer=Adam(learning_rate=0.001))
history_s6 = run_dl_experiment(model_s6, "MLP-S-6: Early Stopping", X_train_processed, Y_train_array, X_val_processed, Y_val_array, epochs=200, callbacks=[early_stopping])
# Out:
# Epoch 1/200
# /home/degide/.mlvenv/lib/python3.13/site-packages/keras/src/layers/activations/leaky_relu.py:41: UserWarning: Argument `alpha` is deprecated. Use `negative_slope` instead.
#   warnings.warn(
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 68ms/step - loss: 201.0747 - mae: 12.0297 - rmse: 14.1801 - val_loss: 117.4582 - val_mae: 8.4960 - val_rmse: 10.8378
# Epoch 2/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 62ms/step - loss: 70.5029 - mae: 6.4658 - rmse: 8.3966 - val_loss: 56.3353 - val_mae: 5.8104 - val_rmse: 7.5057
# Epoch 3/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 65ms/step - loss: 48.2296 - mae: 5.4749 - rmse: 6.9448 - val_loss: 50.0579 - val_mae: 5.4507 - val_rmse: 7.0752
# Epoch 4/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 64ms/step - loss: 44.4898 - mae: 5.2939 - rmse: 6.6701 - val_loss: 46.9843 - val_mae: 5.2908 - val_rmse: 6.8545
# Epoch 5/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 61ms/step - loss: 42.2140 - mae: 5.1571 - rmse: 6.4972 - val_loss: 45.3072 - val_mae: 5.2077 - val_rmse: 6.7311
# Epoch 6/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 71ms/step - loss: 40.7463 - mae: 5.0503 - rmse: 6.3833 - val_loss: 44.1330 - val_mae: 5.1145 - val_rmse: 6.6433
# Epoch 7/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 76ms/step - loss: 39.5341 - mae: 4.9749 - rmse: 6.2876 - val_loss: 43.4418 - val_mae: 5.0558 - val_rmse: 6.5910
# Epoch 8/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 60ms/step - loss: 38.7943 - mae: 4.8964 - rmse: 6.2285 - val_loss: 43.3676 - val_mae: 5.1188 - val_rmse: 6.5854
# Epoch 9/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 61ms/step - loss: 38.3868 - mae: 4.8719 - rmse: 6.1957 - val_loss: 42.6401 - val_mae: 5.0227 - val_rmse: 6.5299
# Epoch 10/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 60ms/step - loss: 37.9299 - mae: 4.8486 - rmse: 6.1587 - val_loss: 42.3698 - val_mae: 5.0123 - val_rmse: 6.5092
# Epoch 11/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 64ms/step - loss: 37.5331 - mae: 4.8000 - rmse: 6.1264 - val_loss: 41.9679 - val_mae: 4.9819 - val_rmse: 6.4783
# Epoch 12/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 59ms/step - loss: 37.1653 - mae: 4.7579 - rmse: 6.0963 - val_loss: 41.9992 - val_mae: 5.0042 - val_rmse: 6.4807
# Epoch 13/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 60ms/step - loss: 36.7528 - mae: 4.7503 - rmse: 6.0624 - val_loss: 41.7411 - val_mae: 4.9905 - val_rmse: 6.4607
# Epoch 14/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 65ms/step - loss: 36.4998 - mae: 4.7021 - rmse: 6.0415 - val_loss: 41.1569 - val_mae: 4.9205 - val_rmse: 6.4154
# Epoch 15/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 71ms/step - loss: 35.8547 - mae: 4.6894 - rmse: 5.9879 - val_loss: 40.8181 - val_mae: 4.8898 - val_rmse: 6.3889
# Epoch 16/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 72ms/step - loss: 35.3965 - mae: 4.6138 - rmse: 5.9495 - val_loss: 40.8581 - val_mae: 4.9410 - val_rmse: 6.3920
# Epoch 17/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 71ms/step - loss: 34.8549 - mae: 4.6045 - rmse: 5.9038 - val_loss: 40.1098 - val_mae: 4.8449 - val_rmse: 6.3332
# Epoch 18/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 68ms/step - loss: 34.4950 - mae: 4.5682 - rmse: 5.8732 - val_loss: 39.8308 - val_mae: 4.8137 - val_rmse: 6.3112
# Epoch 19/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 66ms/step - loss: 33.8906 - mae: 4.5324 - rmse: 5.8216 - val_loss: 39.6407 - val_mae: 4.7972 - val_rmse: 6.2961
# Epoch 20/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 72ms/step - loss: 33.1827 - mae: 4.4875 - rmse: 5.7604 - val_loss: 39.2621 - val_mae: 4.7599 - val_rmse: 6.2659
# Epoch 21/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 71ms/step - loss: 32.6528 - mae: 4.4343 - rmse: 5.7143 - val_loss: 39.0890 - val_mae: 4.7873 - val_rmse: 6.2521
# Epoch 22/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 60ms/step - loss: 32.1191 - mae: 4.4094 - rmse: 5.6674 - val_loss: 38.5789 - val_mae: 4.7117 - val_rmse: 6.2112
# Epoch 23/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 64ms/step - loss: 31.7250 - mae: 4.3584 - rmse: 5.6325 - val_loss: 38.7027 - val_mae: 4.7927 - val_rmse: 6.2212
# Epoch 24/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 62ms/step - loss: 31.0436 - mae: 4.3333 - rmse: 5.5717 - val_loss: 38.1715 - val_mae: 4.7042 - val_rmse: 6.1783
# Epoch 25/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 62ms/step - loss: 30.5137 - mae: 4.2829 - rmse: 5.5239 - val_loss: 38.2404 - val_mae: 4.7196 - val_rmse: 6.1839
# Epoch 26/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 71ms/step - loss: 30.0435 - mae: 4.2539 - rmse: 5.4812 - val_loss: 38.0162 - val_mae: 4.7003 - val_rmse: 6.1657
# Epoch 27/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 69ms/step - loss: 29.6083 - mae: 4.2217 - rmse: 5.4414 - val_loss: 37.9811 - val_mae: 4.6742 - val_rmse: 6.1629
# Epoch 28/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 69ms/step - loss: 29.3475 - mae: 4.1756 - rmse: 5.4173 - val_loss: 38.2115 - val_mae: 4.6719 - val_rmse: 6.1815
# Epoch 29/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 71ms/step - loss: 29.0982 - mae: 4.1453 - rmse: 5.3943 - val_loss: 38.3931 - val_mae: 4.7552 - val_rmse: 6.1962
# Epoch 30/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 67ms/step - loss: 28.7216 - mae: 4.1413 - rmse: 5.3593 - val_loss: 38.3034 - val_mae: 4.7350 - val_rmse: 6.1890
# Epoch 31/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 64ms/step - loss: 28.3027 - mae: 4.0938 - rmse: 5.3200 - val_loss: 38.2863 - val_mae: 4.7027 - val_rmse: 6.1876
# Epoch 32/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 67ms/step - loss: 27.9490 - mae: 4.0644 - rmse: 5.2867 - val_loss: 38.4668 - val_mae: 4.7543 - val_rmse: 6.2022
# Epoch 33/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 64ms/step - loss: 27.8300 - mae: 4.0553 - rmse: 5.2754 - val_loss: 38.4793 - val_mae: 4.6840 - val_rmse: 6.2032
# Epoch 34/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 59ms/step - loss: 27.5835 - mae: 4.0268 - rmse: 5.2520 - val_loss: 39.1529 - val_mae: 4.7924 - val_rmse: 6.2572
# Epoch 35/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 59ms/step - loss: 27.6396 - mae: 4.0236 - rmse: 5.2573 - val_loss: 38.5150 - val_mae: 4.6652 - val_rmse: 6.2060
# Epoch 36/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 62ms/step - loss: 27.0444 - mae: 3.9964 - rmse: 5.2004 - val_loss: 38.5060 - val_mae: 4.6680 - val_rmse: 6.2053
# Epoch 37/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 59ms/step - loss: 26.7429 - mae: 3.9685 - rmse: 5.1714 - val_loss: 38.7624 - val_mae: 4.6942 - val_rmse: 6.2259
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 34.5461 - mae: 4.6808 - rmse: 5.8776
# -> MLP-S-6: Early Stopping: Test RMSE=5.8776, Test R2=0.3640

# %% [markdown]
# The perfomance went up with RMSE at 5.87 and R2 at 0.36. Let's try a different approach in the experiment MLP-S-7 by doing batch optimization.

# %% [markdown]
# ### MLP-S-7: Batch Size Optimization
#
# Let's use a different batch size from the one used in the above experiments while keeping the other parameters to the optimal one observed so far.
#
# Batch size is an important practical hyperparameter. A larger batch size (e.g., 512 vs. 64) provides a more accurate estimate of the gradient but can lead to poorer generalization. This experiment tests the trade-off.

# %%
model_s7 = create_sequential_model(N_FEATURES, layers=[128, 64], activation=tf.keras.layers.LeakyReLU(alpha=0.01), optimizer=Adam(learning_rate=0.001))
history_s7 = model_s7.fit(
        X_train_processed, Y_train_array,
        epochs=EPOCHS,
        batch_size=512, # Testing a larger batch size
        validation_data=(X_val_processed, Y_val_array),
        verbose=VERBOSE
    )
Y_pred_test = model_s7.predict(X_test_processed, verbose=0).flatten()
# Re-evaluating RMSE using the non-deprecated function
rmse = root_mean_squared_error(Y_test_array, Y_pred_test)
r2 = r2_score(Y_test_array, Y_pred_test)

results_dl.append({
    'Model': model_s7.name,
    'Experiment': "MLP-S-7: Batch Size Optimization (512)",
    'Hyperparameters/Settings': "Batch Size: 512",
    'RMSE': f"{rmse:.4f}",
    'R2 Score': f"{r2:.4f}",
    'Final Val Loss': f"{history_s7.history['val_loss'][-1]:.4f}",
    'Notes': model_s7.name.split('_')[0]
})
print(f"-> MLP-S-7: Test RMSE={rmse:.4f}, Test R2={r2:.4f}")
# Out:
# Epoch 1/50
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - loss: 282.8353 - mae: 14.9305 - rmse: 16.8177
# /home/degide/.mlvenv/lib/python3.13/site-packages/keras/src/layers/activations/leaky_relu.py:41: UserWarning: Argument `alpha` is deprecated. Use `negative_slope` instead.
#   warnings.warn(
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - loss: 264.2490 - mae: 14.3953 - rmse: 16.2557 - val_loss: 252.5337 - val_mae: 13.9929 - val_rmse: 15.8913
# Epoch 2/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - loss: 248.8362 - mae: 13.8792 - rmse: 15.7745 - val_loss: 237.7084 - val_mae: 13.4981 - val_rmse: 15.4178
# Epoch 3/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - loss: 233.6256 - mae: 13.3553 - rmse: 15.2848 - val_loss: 221.9612 - val_mae: 12.9483 - val_rmse: 14.8984
# Epoch 4/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - loss: 217.0160 - mae: 12.7578 - rmse: 14.7315 - val_loss: 204.2298 - val_mae: 12.2944 - val_rmse: 14.2909
# Epoch 5/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - loss: 198.1989 - mae: 12.0437 - rmse: 14.0783 - val_loss: 184.0343 - val_mae: 11.5080 - val_rmse: 13.5659
# Epoch 6/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - loss: 176.8062 - mae: 11.1776 - rmse: 13.2968 - val_loss: 161.4318 - val_mae: 10.5624 - val_rmse: 12.7056
# Epoch 7/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - loss: 153.1439 - mae: 10.1597 - rmse: 12.3751 - val_loss: 137.1275 - val_mae: 9.4554 - val_rmse: 11.7101
# Epoch 8/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 128.2035 - mae: 9.0480 - rmse: 11.3227 - val_loss: 112.4959 - val_mae: 8.2650 - val_rmse: 10.6064
# Epoch 9/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 103.5252 - mae: 7.8812 - rmse: 10.1747 - val_loss: 89.8861 - val_mae: 7.0813 - val_rmse: 9.4808
# Epoch 10/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 81.6157 - mae: 6.8308 - rmse: 9.0341 - val_loss: 72.3086 - val_mae: 6.2073 - val_rmse: 8.5034
# Epoch 11/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 65.3615 - mae: 6.0779 - rmse: 8.0846 - val_loss: 62.0936 - val_mae: 5.8279 - val_rmse: 7.8800
# Epoch 12/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - loss: 56.6102 - mae: 5.7768 - rmse: 7.5240 - val_loss: 58.8813 - val_mae: 5.8082 - val_rmse: 7.6734
# Epoch 13/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 53.8670 - mae: 5.7498 - rmse: 7.3394 - val_loss: 58.9137 - val_mae: 5.9252 - val_rmse: 7.6755
# Epoch 14/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 53.1021 - mae: 5.8066 - rmse: 7.2871 - val_loss: 58.0060 - val_mae: 5.9423 - val_rmse: 7.6162
# Epoch 15/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 51.2688 - mae: 5.7376 - rmse: 7.1602 - val_loss: 55.4830 - val_mae: 5.7925 - val_rmse: 7.4487
# Epoch 16/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 102ms/step - loss: 48.9217 - mae: 5.5860 - rmse: 6.9944 - val_loss: 52.9911 - val_mae: 5.6097 - val_rmse: 7.2795
# Epoch 17/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 47.1515 - mae: 5.4445 - rmse: 6.8667 - val_loss: 51.3367 - val_mae: 5.4736 - val_rmse: 7.1650
# Epoch 18/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - loss: 46.1466 - mae: 5.3519 - rmse: 6.7931 - val_loss: 50.3536 - val_mae: 5.3974 - val_rmse: 7.0960
# Epoch 19/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - loss: 45.3973 - mae: 5.2970 - rmse: 6.7377 - val_loss: 49.6216 - val_mae: 5.3625 - val_rmse: 7.0443
# Epoch 20/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - loss: 44.6328 - mae: 5.2595 - rmse: 6.6808 - val_loss: 49.0006 - val_mae: 5.3466 - val_rmse: 7.0000
# Epoch 21/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 43.9355 - mae: 5.2325 - rmse: 6.6284 - val_loss: 48.4682 - val_mae: 5.3410 - val_rmse: 6.9619
# Epoch 22/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 43.3348 - mae: 5.2143 - rmse: 6.5829 - val_loss: 48.0729 - val_mae: 5.3417 - val_rmse: 6.9335
# Epoch 23/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 42.8583 - mae: 5.2006 - rmse: 6.5466 - val_loss: 47.6968 - val_mae: 5.3319 - val_rmse: 6.9063
# Epoch 24/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 42.3768 - mae: 5.1750 - rmse: 6.5097 - val_loss: 47.2300 - val_mae: 5.3032 - val_rmse: 6.8724
# Epoch 25/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 41.9709 - mae: 5.1458 - rmse: 6.4785 - val_loss: 46.8284 - val_mae: 5.2770 - val_rmse: 6.8431
# Epoch 26/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - loss: 41.5706 - mae: 5.1174 - rmse: 6.4475 - val_loss: 46.4288 - val_mae: 5.2497 - val_rmse: 6.8139
# Epoch 27/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - loss: 41.2558 - mae: 5.0929 - rmse: 6.4231 - val_loss: 46.0781 - val_mae: 5.2245 - val_rmse: 6.7881
# Epoch 28/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - loss: 40.9505 - mae: 5.0708 - rmse: 6.3993 - val_loss: 45.7726 - val_mae: 5.2056 - val_rmse: 6.7655
# Epoch 29/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 40.6872 - mae: 5.0565 - rmse: 6.3787 - val_loss: 45.5552 - val_mae: 5.1960 - val_rmse: 6.7495
# Epoch 30/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - loss: 40.4149 - mae: 5.0396 - rmse: 6.3573 - val_loss: 45.2885 - val_mae: 5.1776 - val_rmse: 6.7297
# Epoch 31/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - loss: 40.1555 - mae: 5.0203 - rmse: 6.3368 - val_loss: 45.0541 - val_mae: 5.1606 - val_rmse: 6.7122
# Epoch 32/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - loss: 39.9394 - mae: 5.0067 - rmse: 6.3198 - val_loss: 44.8436 - val_mae: 5.1523 - val_rmse: 6.6965
# Epoch 33/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 39.7133 - mae: 4.9930 - rmse: 6.3018 - val_loss: 44.6260 - val_mae: 5.1356 - val_rmse: 6.6803
# Epoch 34/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 39.5276 - mae: 4.9784 - rmse: 6.2871 - val_loss: 44.4563 - val_mae: 5.1237 - val_rmse: 6.6676
# Epoch 35/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 39.3563 - mae: 4.9633 - rmse: 6.2735 - val_loss: 44.2978 - val_mae: 5.1110 - val_rmse: 6.6557
# Epoch 36/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 39.1651 - mae: 4.9484 - rmse: 6.2582 - val_loss: 44.1769 - val_mae: 5.1039 - val_rmse: 6.6466
# Epoch 37/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 39.0028 - mae: 4.9366 - rmse: 6.2452 - val_loss: 44.0538 - val_mae: 5.0956 - val_rmse: 6.6373
# Epoch 38/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 38.8509 - mae: 4.9208 - rmse: 6.2330 - val_loss: 43.8548 - val_mae: 5.0770 - val_rmse: 6.6223
# Epoch 39/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 38.6859 - mae: 4.9047 - rmse: 6.2198 - val_loss: 43.7233 - val_mae: 5.0674 - val_rmse: 6.6124
# Epoch 40/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 38.5502 - mae: 4.8940 - rmse: 6.2089 - val_loss: 43.5912 - val_mae: 5.0614 - val_rmse: 6.6024
# Epoch 41/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 38.4118 - mae: 4.8840 - rmse: 6.1977 - val_loss: 43.4389 - val_mae: 5.0486 - val_rmse: 6.5908
# Epoch 42/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 38.2873 - mae: 4.8716 - rmse: 6.1877 - val_loss: 43.3050 - val_mae: 5.0383 - val_rmse: 6.5807
# Epoch 43/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 38.1493 - mae: 4.8637 - rmse: 6.1765 - val_loss: 43.1986 - val_mae: 5.0345 - val_rmse: 6.5726
# Epoch 44/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - loss: 38.0291 - mae: 4.8551 - rmse: 6.1668 - val_loss: 43.0846 - val_mae: 5.0268 - val_rmse: 6.5639
# Epoch 45/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - loss: 37.9076 - mae: 4.8461 - rmse: 6.1569 - val_loss: 43.0134 - val_mae: 5.0254 - val_rmse: 6.5585
# Epoch 46/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 37.7847 - mae: 4.8380 - rmse: 6.1469 - val_loss: 42.9692 - val_mae: 5.0244 - val_rmse: 6.5551
# Epoch 47/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 37.6668 - mae: 4.8332 - rmse: 6.1373 - val_loss: 42.9047 - val_mae: 5.0237 - val_rmse: 6.5502
# Epoch 48/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 37.5632 - mae: 4.8249 - rmse: 6.1289 - val_loss: 42.7530 - val_mae: 5.0096 - val_rmse: 6.5386
# Epoch 49/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 37.4516 - mae: 4.8131 - rmse: 6.1198 - val_loss: 42.6662 - val_mae: 5.0040 - val_rmse: 6.5319
# Epoch 50/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - loss: 37.3522 - mae: 4.8063 - rmse: 6.1116 - val_loss: 42.5958 - val_mae: 4.9993 - val_rmse: 6.5265
# -> MLP-S-7: Test RMSE=6.1801, Test R2=0.2968

# %% [markdown]
# From the above results, increasing the batch size proves to be less effective. The RMSE went up again to 6.18 and R2 went down to 0.29. This shows that this optimization is outperformed by previous experiment.
#
# After all, we can conclude that by further tuning the hyperparameters, we might achieve a much better performance compared to RFR models. It is observed from above experiments we achieved R2 which is close to RFR best R2 and from that we can fine tune the parameters to improve the RMSE. However, the overall results shows that RFR models are outperforming the MLP models.

# %% [markdown]
# ## 3.2 Model 4: Multi-Layer Perceptron (MLP)

# %% [markdown]
# ### MLP-F-1: Functional API Baseline
#
# Let's recreate the best Sequential architecture (128, 64 layers and leaky relu) using the more flexible Functional API. This establishes a control to ensure that subsequent, more complex Functional experiments are compared against a known baseline.

# %%
model_f1 = create_functional_model(N_FEATURES, layers=[128, 64], activation=tf.keras.layers.LeakyReLU(alpha=0.01), optimizer=Adam(learning_rate=0.001))
history_f1 = run_dl_experiment(model_f1, "MLP-F-1: Functional API Baseline", X_train_processed, Y_train_array, X_val_processed, Y_val_array)
# Out:
# Epoch 1/50
#  1/37 ━━━━━━━━━━━━━━━━━━━━ 3s 96ms/step - loss: 286.6895 - mae: 14.7508 - rmse: 16.9319
# /home/degide/.mlvenv/lib/python3.13/site-packages/keras/src/layers/activations/leaky_relu.py:41: UserWarning: Argument `alpha` is deprecated. Use `negative_slope` instead.
#   warnings.warn(
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 64ms/step - loss: 219.4674 - mae: 12.6881 - rmse: 14.8144 - val_loss: 144.9817 - val_mae: 9.6965 - val_rmse: 12.0408
# Epoch 2/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 60ms/step - loss: 80.5241 - mae: 6.9168 - rmse: 8.9735 - val_loss: 61.0839 - val_mae: 6.2044 - val_rmse: 7.8156
# Epoch 3/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 66ms/step - loss: 50.5647 - mae: 5.6503 - rmse: 7.1109 - val_loss: 50.9124 - val_mae: 5.4547 - val_rmse: 7.1353
# Epoch 4/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 61ms/step - loss: 44.7350 - mae: 5.3231 - rmse: 6.6884 - val_loss: 47.5903 - val_mae: 5.3221 - val_rmse: 6.8986
# Epoch 5/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 60ms/step - loss: 42.2233 - mae: 5.1612 - rmse: 6.4979 - val_loss: 45.7521 - val_mae: 5.2171 - val_rmse: 6.7640
# Epoch 6/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - loss: 40.6340 - mae: 5.0666 - rmse: 6.3745 - val_loss: 44.4144 - val_mae: 5.0826 - val_rmse: 6.6644
# Epoch 7/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - loss: 39.6477 - mae: 4.9615 - rmse: 6.2966 - val_loss: 44.2014 - val_mae: 5.1496 - val_rmse: 6.6484
# Epoch 8/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 62ms/step - loss: 38.7454 - mae: 4.9057 - rmse: 6.2246 - val_loss: 42.9706 - val_mae: 5.0317 - val_rmse: 6.5552
# Epoch 9/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 68ms/step - loss: 38.2160 - mae: 4.8564 - rmse: 6.1819 - val_loss: 42.3954 - val_mae: 4.9467 - val_rmse: 6.5112
# Epoch 10/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 68ms/step - loss: 37.7649 - mae: 4.8219 - rmse: 6.1453 - val_loss: 42.0021 - val_mae: 4.9460 - val_rmse: 6.4809
# Epoch 11/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 63ms/step - loss: 37.0524 - mae: 4.7879 - rmse: 6.0871 - val_loss: 41.6321 - val_mae: 4.9234 - val_rmse: 6.4523
# Epoch 12/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 68ms/step - loss: 36.6954 - mae: 4.7255 - rmse: 6.0577 - val_loss: 41.1169 - val_mae: 4.8976 - val_rmse: 6.4122
# Epoch 13/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 71ms/step - loss: 35.9345 - mae: 4.6896 - rmse: 5.9945 - val_loss: 41.4875 - val_mae: 5.0026 - val_rmse: 6.4411
# Epoch 14/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 60ms/step - loss: 35.5572 - mae: 4.6520 - rmse: 5.9630 - val_loss: 40.4549 - val_mae: 4.8844 - val_rmse: 6.3604
# Epoch 15/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 70ms/step - loss: 34.9472 - mae: 4.6025 - rmse: 5.9116 - val_loss: 40.0548 - val_mae: 4.8644 - val_rmse: 6.3289
# Epoch 16/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 74ms/step - loss: 34.3346 - mae: 4.5837 - rmse: 5.8596 - val_loss: 39.4810 - val_mae: 4.7900 - val_rmse: 6.2834
# Epoch 17/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 74ms/step - loss: 33.6283 - mae: 4.5204 - rmse: 5.7990 - val_loss: 39.3305 - val_mae: 4.8166 - val_rmse: 6.2714
# Epoch 18/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 72ms/step - loss: 33.1374 - mae: 4.4718 - rmse: 5.7565 - val_loss: 38.7553 - val_mae: 4.7411 - val_rmse: 6.2254
# Epoch 19/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 67ms/step - loss: 32.4478 - mae: 4.4235 - rmse: 5.6963 - val_loss: 38.6264 - val_mae: 4.7793 - val_rmse: 6.2150
# Epoch 20/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 70ms/step - loss: 32.0630 - mae: 4.3819 - rmse: 5.6624 - val_loss: 38.2156 - val_mae: 4.7660 - val_rmse: 6.1819
# Epoch 21/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 74ms/step - loss: 31.4670 - mae: 4.3613 - rmse: 5.6095 - val_loss: 38.7554 - val_mae: 4.8253 - val_rmse: 6.2254
# Epoch 22/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 67ms/step - loss: 31.0355 - mae: 4.3205 - rmse: 5.5709 - val_loss: 38.1296 - val_mae: 4.7521 - val_rmse: 6.1749
# Epoch 23/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 73ms/step - loss: 30.4472 - mae: 4.2672 - rmse: 5.5179 - val_loss: 37.6925 - val_mae: 4.6714 - val_rmse: 6.1394
# Epoch 24/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 75ms/step - loss: 30.0338 - mae: 4.2572 - rmse: 5.4803 - val_loss: 37.3083 - val_mae: 4.6442 - val_rmse: 6.1081
# Epoch 25/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 64ms/step - loss: 29.6729 - mae: 4.2027 - rmse: 5.4473 - val_loss: 37.7258 - val_mae: 4.7321 - val_rmse: 6.1421
# Epoch 26/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 71ms/step - loss: 29.3000 - mae: 4.1757 - rmse: 5.4130 - val_loss: 37.3606 - val_mae: 4.6914 - val_rmse: 6.1123
# Epoch 27/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 67ms/step - loss: 28.9741 - mae: 4.1557 - rmse: 5.3828 - val_loss: 37.4600 - val_mae: 4.6140 - val_rmse: 6.1205
# Epoch 28/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 70ms/step - loss: 28.6804 - mae: 4.0958 - rmse: 5.3554 - val_loss: 37.0589 - val_mae: 4.6064 - val_rmse: 6.0876
# Epoch 29/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 61ms/step - loss: 28.1322 - mae: 4.0907 - rmse: 5.3040 - val_loss: 37.1446 - val_mae: 4.6230 - val_rmse: 6.0946
# Epoch 30/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - loss: 27.9209 - mae: 4.0473 - rmse: 5.2840 - val_loss: 37.0018 - val_mae: 4.6350 - val_rmse: 6.0829
# Epoch 31/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - loss: 27.6471 - mae: 4.0380 - rmse: 5.2581 - val_loss: 37.2108 - val_mae: 4.5720 - val_rmse: 6.1001
# Epoch 32/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - loss: 27.3280 - mae: 3.9898 - rmse: 5.2276 - val_loss: 37.1236 - val_mae: 4.6214 - val_rmse: 6.0929
# Epoch 33/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - loss: 27.2605 - mae: 3.9965 - rmse: 5.2212 - val_loss: 37.3260 - val_mae: 4.6349 - val_rmse: 6.1095
# Epoch 34/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - loss: 26.8719 - mae: 3.9547 - rmse: 5.1838 - val_loss: 37.0229 - val_mae: 4.5800 - val_rmse: 6.0846
# Epoch 35/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - loss: 26.6303 - mae: 3.9254 - rmse: 5.1605 - val_loss: 37.4935 - val_mae: 4.6598 - val_rmse: 6.1232
# Epoch 36/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - loss: 26.3954 - mae: 3.9310 - rmse: 5.1376 - val_loss: 37.4152 - val_mae: 4.5970 - val_rmse: 6.1168
# Epoch 37/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 62ms/step - loss: 26.1285 - mae: 3.8899 - rmse: 5.1116 - val_loss: 37.2604 - val_mae: 4.6128 - val_rmse: 6.1041
# Epoch 38/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 64ms/step - loss: 25.9671 - mae: 3.8874 - rmse: 5.0958 - val_loss: 37.3777 - val_mae: 4.6124 - val_rmse: 6.1137
# Epoch 39/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - loss: 25.6654 - mae: 3.8339 - rmse: 5.0661 - val_loss: 37.5805 - val_mae: 4.6511 - val_rmse: 6.1303
# Epoch 40/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - loss: 25.4864 - mae: 3.8478 - rmse: 5.0484 - val_loss: 37.4084 - val_mae: 4.5973 - val_rmse: 6.1162
# Epoch 41/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - loss: 25.3448 - mae: 3.8256 - rmse: 5.0344 - val_loss: 38.0134 - val_mae: 4.6342 - val_rmse: 6.1655
# Epoch 42/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - loss: 25.5183 - mae: 3.8350 - rmse: 5.0516 - val_loss: 37.7219 - val_mae: 4.6304 - val_rmse: 6.1418
# Epoch 43/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - loss: 25.1172 - mae: 3.8028 - rmse: 5.0117 - val_loss: 37.6353 - val_mae: 4.6174 - val_rmse: 6.1348
# Epoch 44/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - loss: 24.9128 - mae: 3.7973 - rmse: 4.9913 - val_loss: 37.9122 - val_mae: 4.6170 - val_rmse: 6.1573
# Epoch 45/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - loss: 24.8272 - mae: 3.7754 - rmse: 4.9827 - val_loss: 37.7301 - val_mae: 4.6324 - val_rmse: 6.1425
# Epoch 46/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 56ms/step - loss: 24.4449 - mae: 3.7392 - rmse: 4.9442 - val_loss: 37.9219 - val_mae: 4.6476 - val_rmse: 6.1581
# Epoch 47/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - loss: 24.3296 - mae: 3.7460 - rmse: 4.9325 - val_loss: 38.0414 - val_mae: 4.6635 - val_rmse: 6.1678
# Epoch 48/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - loss: 24.1138 - mae: 3.7083 - rmse: 4.9106 - val_loss: 38.1262 - val_mae: 4.6630 - val_rmse: 6.1746
# Epoch 49/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - loss: 24.0104 - mae: 3.7150 - rmse: 4.9000 - val_loss: 38.1597 - val_mae: 4.6863 - val_rmse: 6.1774
# Epoch 50/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - loss: 23.8158 - mae: 3.6815 - rmse: 4.8801 - val_loss: 37.9345 - val_mae: 4.6335 - val_rmse: 6.1591
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 35.4843 - mae: 4.6297 - rmse: 5.9569
# -> MLP-F-1: Functional API Baseline: Test RMSE=5.9569, Test R2=0.3467

# %% [markdown]
# The results still shows lower performance than that of RFR models but comparatively on average with the sequential models.

# %% [markdown]
# ### MLP-F-2: L2 Regularization Implementation
#
# Using the hyperparameters from the previous experiment, let's implement $\mathbf{L_2}$ Kernel Regularization to constrain the weight magnitudes. This is a critical technique to control model complexity and prevent overfitting in deep architectures, directly fulfilling the "regularization methods" requirement.

# %%
regularizer = tf.keras.regularizers.l2(0.001)
model_f2 = create_functional_model(N_FEATURES, layers=[128, 64], activation=tf.keras.layers.LeakyReLU(alpha=0.01), regularizer=regularizer, optimizer=Adam(learning_rate=0.001))
history_f2 = run_dl_experiment(model_f2, "MLP-F-2: L2 Regularization", X_train_processed, Y_train_array, X_val_processed, Y_val_array)
# Out:
# Epoch 1/50
#  1/37 ━━━━━━━━━━━━━━━━━━━━ 3s 101ms/step - loss: 289.5116 - mae: 14.9262 - rmse: 17.0104
# /home/degide/.mlvenv/lib/python3.13/site-packages/keras/src/layers/activations/leaky_relu.py:41: UserWarning: Argument `alpha` is deprecated. Use `negative_slope` instead.
#   warnings.warn(
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 69ms/step - loss: 214.9888 - mae: 12.5460 - rmse: 14.6570 - val_loss: 139.6767 - val_mae: 9.5229 - val_rmse: 11.8113
# Epoch 2/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 73ms/step - loss: 78.5642 - mae: 6.7997 - rmse: 8.8532 - val_loss: 60.8229 - val_mae: 6.0707 - val_rmse: 7.7864
# Epoch 3/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 76ms/step - loss: 50.1505 - mae: 5.5868 - rmse: 7.0681 - val_loss: 51.5801 - val_mae: 5.4949 - val_rmse: 7.1685
# Epoch 4/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 72ms/step - loss: 45.0361 - mae: 5.3000 - rmse: 6.6965 - val_loss: 47.9817 - val_mae: 5.3063 - val_rmse: 6.9129
# Epoch 5/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 69ms/step - loss: 42.2770 - mae: 5.1500 - rmse: 6.4871 - val_loss: 46.3832 - val_mae: 5.2808 - val_rmse: 6.7961
# Epoch 6/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 74ms/step - loss: 40.8162 - mae: 5.0725 - rmse: 6.3734 - val_loss: 44.7740 - val_mae: 5.1082 - val_rmse: 6.6767
# Epoch 7/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 71ms/step - loss: 39.8214 - mae: 4.9535 - rmse: 6.2948 - val_loss: 43.8222 - val_mae: 5.0630 - val_rmse: 6.6049
# Epoch 8/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 65ms/step - loss: 38.9906 - mae: 4.8764 - rmse: 6.2284 - val_loss: 43.7438 - val_mae: 5.1184 - val_rmse: 6.5989
# Epoch 9/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 65ms/step - loss: 38.2492 - mae: 4.8597 - rmse: 6.1685 - val_loss: 42.7794 - val_mae: 4.9325 - val_rmse: 6.5254
# Epoch 10/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 65ms/step - loss: 37.9714 - mae: 4.8266 - rmse: 6.1459 - val_loss: 42.3009 - val_mae: 4.9574 - val_rmse: 6.4885
# Epoch 11/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 65ms/step - loss: 37.4319 - mae: 4.7769 - rmse: 6.1018 - val_loss: 42.1081 - val_mae: 4.9308 - val_rmse: 6.4736
# Epoch 12/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 65ms/step - loss: 36.9195 - mae: 4.7202 - rmse: 6.0595 - val_loss: 41.9402 - val_mae: 4.9653 - val_rmse: 6.4605
# Epoch 13/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 64ms/step - loss: 36.6083 - mae: 4.7181 - rmse: 6.0337 - val_loss: 41.2474 - val_mae: 4.8957 - val_rmse: 6.4065
# Epoch 14/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 68ms/step - loss: 36.0645 - mae: 4.6550 - rmse: 5.9883 - val_loss: 41.0364 - val_mae: 4.8914 - val_rmse: 6.3899
# Epoch 15/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 65ms/step - loss: 35.5545 - mae: 4.6274 - rmse: 5.9454 - val_loss: 40.6401 - val_mae: 4.8475 - val_rmse: 6.3587
# Epoch 16/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 69ms/step - loss: 35.1400 - mae: 4.5847 - rmse: 5.9103 - val_loss: 40.4805 - val_mae: 4.8632 - val_rmse: 6.3459
# Epoch 17/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 69ms/step - loss: 34.6403 - mae: 4.5626 - rmse: 5.8676 - val_loss: 39.8431 - val_mae: 4.7412 - val_rmse: 6.2953
# Epoch 18/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 67ms/step - loss: 34.3847 - mae: 4.5315 - rmse: 5.8456 - val_loss: 39.2915 - val_mae: 4.7164 - val_rmse: 6.2511
# Epoch 19/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 67ms/step - loss: 33.6864 - mae: 4.4872 - rmse: 5.7853 - val_loss: 39.0306 - val_mae: 4.7416 - val_rmse: 6.2299
# Epoch 20/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 71ms/step - loss: 33.1199 - mae: 4.4567 - rmse: 5.7358 - val_loss: 38.8105 - val_mae: 4.6838 - val_rmse: 6.2120
# Epoch 21/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 71ms/step - loss: 33.0542 - mae: 4.4145 - rmse: 5.7298 - val_loss: 39.9285 - val_mae: 4.9235 - val_rmse: 6.3010
# Epoch 22/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 72ms/step - loss: 32.5422 - mae: 4.4299 - rmse: 5.6847 - val_loss: 38.7618 - val_mae: 4.7873 - val_rmse: 6.2075
# Epoch 23/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 72ms/step - loss: 31.8713 - mae: 4.3515 - rmse: 5.6250 - val_loss: 38.1815 - val_mae: 4.6806 - val_rmse: 6.1603
# Epoch 24/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 73ms/step - loss: 31.4749 - mae: 4.3395 - rmse: 5.5894 - val_loss: 38.0794 - val_mae: 4.6342 - val_rmse: 6.1518
# Epoch 25/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 76ms/step - loss: 31.1196 - mae: 4.2964 - rmse: 5.5572 - val_loss: 37.8533 - val_mae: 4.6692 - val_rmse: 6.1331
# Epoch 26/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 80ms/step - loss: 30.8343 - mae: 4.2879 - rmse: 5.5312 - val_loss: 37.9128 - val_mae: 4.6990 - val_rmse: 6.1376
# Epoch 27/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 82ms/step - loss: 30.3210 - mae: 4.2521 - rmse: 5.4842 - val_loss: 37.7780 - val_mae: 4.6482 - val_rmse: 6.1264
# Epoch 28/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 85ms/step - loss: 29.9088 - mae: 4.1929 - rmse: 5.4462 - val_loss: 37.8147 - val_mae: 4.6890 - val_rmse: 6.1291
# Epoch 29/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 75ms/step - loss: 29.4896 - mae: 4.1742 - rmse: 5.4073 - val_loss: 37.9696 - val_mae: 4.7485 - val_rmse: 6.1414
# Epoch 30/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 81ms/step - loss: 29.2724 - mae: 4.1675 - rmse: 5.3868 - val_loss: 37.6321 - val_mae: 4.6601 - val_rmse: 6.1136
# Epoch 31/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 72ms/step - loss: 29.0417 - mae: 4.1439 - rmse: 5.3651 - val_loss: 37.7797 - val_mae: 4.6446 - val_rmse: 6.1254
# Epoch 32/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 66ms/step - loss: 28.7465 - mae: 4.1091 - rmse: 5.3372 - val_loss: 37.7917 - val_mae: 4.6851 - val_rmse: 6.1261
# Epoch 33/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 70ms/step - loss: 28.5416 - mae: 4.1029 - rmse: 5.3176 - val_loss: 37.7708 - val_mae: 4.6645 - val_rmse: 6.1242
# Epoch 34/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 70ms/step - loss: 28.1513 - mae: 4.0529 - rmse: 5.2806 - val_loss: 38.0622 - val_mae: 4.6377 - val_rmse: 6.1477
# Epoch 35/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 72ms/step - loss: 27.9453 - mae: 4.0279 - rmse: 5.2607 - val_loss: 38.5178 - val_mae: 4.7650 - val_rmse: 6.1843
# Epoch 36/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 73ms/step - loss: 27.8767 - mae: 4.0114 - rmse: 5.2539 - val_loss: 38.6265 - val_mae: 4.7800 - val_rmse: 6.1929
# Epoch 37/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 72ms/step - loss: 27.6866 - mae: 4.0163 - rmse: 5.2355 - val_loss: 38.5855 - val_mae: 4.7572 - val_rmse: 6.1893
# Epoch 38/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 75ms/step - loss: 27.6231 - mae: 4.0078 - rmse: 5.2291 - val_loss: 38.2279 - val_mae: 4.6484 - val_rmse: 6.1602
# Epoch 39/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 71ms/step - loss: 27.0703 - mae: 3.9705 - rmse: 5.1758 - val_loss: 38.2803 - val_mae: 4.6385 - val_rmse: 6.1642
# Epoch 40/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 79ms/step - loss: 26.9022 - mae: 3.9283 - rmse: 5.1592 - val_loss: 39.0043 - val_mae: 4.7956 - val_rmse: 6.2224
# Epoch 41/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 78ms/step - loss: 26.8074 - mae: 3.9506 - rmse: 5.1498 - val_loss: 39.0810 - val_mae: 4.7954 - val_rmse: 6.2283
# Epoch 42/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 75ms/step - loss: 26.4034 - mae: 3.9102 - rmse: 5.1101 - val_loss: 38.4741 - val_mae: 4.7134 - val_rmse: 6.1792
# Epoch 43/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 75ms/step - loss: 26.1980 - mae: 3.8815 - rmse: 5.0897 - val_loss: 38.8921 - val_mae: 4.7750 - val_rmse: 6.2127
# Epoch 44/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 64ms/step - loss: 25.9541 - mae: 3.8674 - rmse: 5.0654 - val_loss: 38.8118 - val_mae: 4.6732 - val_rmse: 6.2061
# Epoch 45/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 76ms/step - loss: 26.1041 - mae: 3.8785 - rmse: 5.0799 - val_loss: 38.6299 - val_mae: 4.7082 - val_rmse: 6.1911
# Epoch 46/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 71ms/step - loss: 25.6520 - mae: 3.8397 - rmse: 5.0350 - val_loss: 39.2271 - val_mae: 4.7504 - val_rmse: 6.2389
# Epoch 47/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 82ms/step - loss: 25.4975 - mae: 3.8382 - rmse: 5.0193 - val_loss: 38.8660 - val_mae: 4.6682 - val_rmse: 6.2098
# Epoch 48/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 86ms/step - loss: 25.3477 - mae: 3.8137 - rmse: 5.0041 - val_loss: 38.8402 - val_mae: 4.6830 - val_rmse: 6.2075
# Epoch 49/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 74ms/step - loss: 25.1921 - mae: 3.7927 - rmse: 4.9883 - val_loss: 39.2344 - val_mae: 4.7264 - val_rmse: 6.2389
# Epoch 50/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 69ms/step - loss: 24.8790 - mae: 3.7603 - rmse: 4.9565 - val_loss: 39.1789 - val_mae: 4.7718 - val_rmse: 6.2342
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 35.7924 - mae: 4.7254 - rmse: 5.9564
# -> MLP-F-2: L2 Regularization: Test RMSE=5.9564, Test R2=0.3468

# %% [markdown]
# This experiment slightly changes the results we have seen in the previous experiment MLP-F-1.

# %% [markdown]
# ### MLP-F-3: Dropout Regularization Implementation
#
# Next, Let's add in dropout.
#
# Dropout layers randomly deactivate a fraction of neurons during training. This acts as a powerful form of regularization by preventing feature co-adaptation and forcing the network to learn more robust representations.

# %%
# Dropout is handled within the create_functional_model function
regularizer = tf.keras.regularizers.l2(0.001)
model_f3 = create_functional_model(N_FEATURES, layers=[128, 64], activation=tf.keras.layers.LeakyReLU(alpha=0.01), regularizer=regularizer, dropout_rate=0.2, optimizer=Adam(learning_rate=0.001))
history_f3 = run_dl_experiment(model_f3, "MLP-F-3: Dropout Regularization (0.2)", X_train_processed, Y_train_array, X_val_processed, Y_val_array)
# Out:
# Epoch 1/50
# /home/degide/.mlvenv/lib/python3.13/site-packages/keras/src/layers/activations/leaky_relu.py:41: UserWarning: Argument `alpha` is deprecated. Use `negative_slope` instead.
#   warnings.warn(
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 82ms/step - loss: 205.8906 - mae: 12.2589 - rmse: 14.3432 - val_loss: 129.2491 - val_mae: 9.0177 - val_rmse: 11.3612
# Epoch 2/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 89ms/step - loss: 77.7570 - mae: 6.7818 - rmse: 8.8075 - val_loss: 58.1427 - val_mae: 5.9127 - val_rmse: 7.6125
# Epoch 3/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 92ms/step - loss: 51.2569 - mae: 5.6145 - rmse: 7.1460 - val_loss: 50.8816 - val_mae: 5.4598 - val_rmse: 7.1198
# Epoch 4/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 100ms/step - loss: 47.0704 - mae: 5.3807 - rmse: 6.8468 - val_loss: 47.9233 - val_mae: 5.3037 - val_rmse: 6.9088
# Epoch 5/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 86ms/step - loss: 45.4714 - mae: 5.3395 - rmse: 6.7290 - val_loss: 46.1371 - val_mae: 5.2548 - val_rmse: 6.7782
# Epoch 6/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 90ms/step - loss: 44.6693 - mae: 5.2490 - rmse: 6.6691 - val_loss: 44.8387 - val_mae: 5.1450 - val_rmse: 6.6817
# Epoch 7/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 92ms/step - loss: 42.3001 - mae: 5.1221 - rmse: 6.4890 - val_loss: 43.9034 - val_mae: 5.0946 - val_rmse: 6.6113
# Epoch 8/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 84ms/step - loss: 42.1252 - mae: 5.1134 - rmse: 6.4754 - val_loss: 43.4436 - val_mae: 5.0487 - val_rmse: 6.5764
# Epoch 9/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 78ms/step - loss: 41.5002 - mae: 5.0073 - rmse: 6.4269 - val_loss: 42.9889 - val_mae: 4.9686 - val_rmse: 6.5418
# Epoch 10/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 79ms/step - loss: 42.2675 - mae: 5.0764 - rmse: 6.4863 - val_loss: 42.7332 - val_mae: 4.9862 - val_rmse: 6.5221
# Epoch 11/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 78ms/step - loss: 41.1488 - mae: 5.0027 - rmse: 6.3994 - val_loss: 42.2636 - val_mae: 4.9647 - val_rmse: 6.4859
# Epoch 12/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 79ms/step - loss: 40.1753 - mae: 4.9495 - rmse: 6.3229 - val_loss: 42.6645 - val_mae: 5.0619 - val_rmse: 6.5166
# Epoch 13/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 78ms/step - loss: 40.6421 - mae: 4.8960 - rmse: 6.3596 - val_loss: 41.6432 - val_mae: 4.9163 - val_rmse: 6.4378
# Epoch 14/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 78ms/step - loss: 39.2951 - mae: 4.8973 - rmse: 6.2527 - val_loss: 41.4753 - val_mae: 4.9182 - val_rmse: 6.4246
# Epoch 15/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 79ms/step - loss: 38.4837 - mae: 4.8392 - rmse: 6.1874 - val_loss: 41.1197 - val_mae: 4.9213 - val_rmse: 6.3968
# Epoch 16/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 86ms/step - loss: 38.9557 - mae: 4.8491 - rmse: 6.2253 - val_loss: 40.7191 - val_mae: 4.8697 - val_rmse: 6.3653
# Epoch 17/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 90ms/step - loss: 38.1031 - mae: 4.7958 - rmse: 6.1563 - val_loss: 40.4223 - val_mae: 4.8622 - val_rmse: 6.3418
# Epoch 18/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 104ms/step - loss: 38.0334 - mae: 4.7765 - rmse: 6.1505 - val_loss: 40.2351 - val_mae: 4.8221 - val_rmse: 6.3269
# Epoch 19/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 90ms/step - loss: 37.6438 - mae: 4.7367 - rmse: 6.1186 - val_loss: 39.9813 - val_mae: 4.7772 - val_rmse: 6.3068
# Epoch 20/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 79ms/step - loss: 36.3742 - mae: 4.6970 - rmse: 6.0138 - val_loss: 39.8628 - val_mae: 4.7641 - val_rmse: 6.2972
# Epoch 21/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 81ms/step - loss: 37.4843 - mae: 4.7255 - rmse: 6.1053 - val_loss: 40.0607 - val_mae: 4.7866 - val_rmse: 6.3128
# Epoch 22/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 92ms/step - loss: 37.2865 - mae: 4.7271 - rmse: 6.0890 - val_loss: 39.3157 - val_mae: 4.7535 - val_rmse: 6.2533
# Epoch 23/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 79ms/step - loss: 35.8069 - mae: 4.6554 - rmse: 5.9661 - val_loss: 39.0877 - val_mae: 4.7341 - val_rmse: 6.2349
# Epoch 24/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 88ms/step - loss: 36.3539 - mae: 4.6698 - rmse: 6.0116 - val_loss: 38.9140 - val_mae: 4.7759 - val_rmse: 6.2208
# Epoch 25/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 95ms/step - loss: 35.5541 - mae: 4.5824 - rmse: 5.9445 - val_loss: 38.7163 - val_mae: 4.7748 - val_rmse: 6.2047
# Epoch 26/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 84ms/step - loss: 36.4002 - mae: 4.6536 - rmse: 6.0151 - val_loss: 38.6514 - val_mae: 4.7862 - val_rmse: 6.1993
# Epoch 27/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - loss: 35.6819 - mae: 4.6003 - rmse: 5.9550 - val_loss: 38.5140 - val_mae: 4.7867 - val_rmse: 6.1881
# Epoch 28/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 88ms/step - loss: 35.3668 - mae: 4.6305 - rmse: 5.9283 - val_loss: 38.4003 - val_mae: 4.6970 - val_rmse: 6.1788
# Epoch 29/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 87ms/step - loss: 35.0440 - mae: 4.5891 - rmse: 5.9008 - val_loss: 38.3945 - val_mae: 4.7343 - val_rmse: 6.1781
# Epoch 30/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - loss: 34.2599 - mae: 4.5576 - rmse: 5.8339 - val_loss: 38.0049 - val_mae: 4.6840 - val_rmse: 6.1465
# Epoch 31/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 102ms/step - loss: 33.7725 - mae: 4.4765 - rmse: 5.7918 - val_loss: 37.8541 - val_mae: 4.6766 - val_rmse: 6.1340
# Epoch 32/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 82ms/step - loss: 34.5773 - mae: 4.5391 - rmse: 5.8607 - val_loss: 38.0311 - val_mae: 4.7556 - val_rmse: 6.1482
# Epoch 33/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 82ms/step - loss: 34.0423 - mae: 4.4798 - rmse: 5.8148 - val_loss: 38.0133 - val_mae: 4.6634 - val_rmse: 6.1467
# Epoch 34/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 83ms/step - loss: 34.3073 - mae: 4.4884 - rmse: 5.8374 - val_loss: 38.2563 - val_mae: 4.6557 - val_rmse: 6.1664
# Epoch 35/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 85ms/step - loss: 33.1555 - mae: 4.4520 - rmse: 5.7377 - val_loss: 37.8398 - val_mae: 4.6519 - val_rmse: 6.1323
# Epoch 36/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 89ms/step - loss: 33.4802 - mae: 4.4511 - rmse: 5.7658 - val_loss: 37.7947 - val_mae: 4.6646 - val_rmse: 6.1286
# Epoch 37/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - loss: 32.6127 - mae: 4.4164 - rmse: 5.6900 - val_loss: 37.6606 - val_mae: 4.7011 - val_rmse: 6.1174
# Epoch 38/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 107ms/step - loss: 33.6227 - mae: 4.4769 - rmse: 5.7779 - val_loss: 37.5066 - val_mae: 4.6536 - val_rmse: 6.1047
# Epoch 39/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - loss: 33.1044 - mae: 4.4302 - rmse: 5.7327 - val_loss: 37.5070 - val_mae: 4.6582 - val_rmse: 6.1046
# Epoch 40/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 81ms/step - loss: 32.5815 - mae: 4.4042 - rmse: 5.6868 - val_loss: 37.3630 - val_mae: 4.6581 - val_rmse: 6.0926
# Epoch 41/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 79ms/step - loss: 32.1142 - mae: 4.3980 - rmse: 5.6454 - val_loss: 37.3756 - val_mae: 4.6895 - val_rmse: 6.0935
# Epoch 42/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 89ms/step - loss: 32.3751 - mae: 4.3698 - rmse: 5.6683 - val_loss: 37.1475 - val_mae: 4.6181 - val_rmse: 6.0747
# Epoch 43/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 82ms/step - loss: 32.9080 - mae: 4.4447 - rmse: 5.7151 - val_loss: 37.3820 - val_mae: 4.6796 - val_rmse: 6.0938
# Epoch 44/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 98ms/step - loss: 32.1269 - mae: 4.3300 - rmse: 5.6462 - val_loss: 37.1281 - val_mae: 4.6159 - val_rmse: 6.0729
# Epoch 45/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 82ms/step - loss: 31.7380 - mae: 4.3673 - rmse: 5.6115 - val_loss: 37.1663 - val_mae: 4.6346 - val_rmse: 6.0758
# Epoch 46/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 86ms/step - loss: 32.2273 - mae: 4.3543 - rmse: 5.6548 - val_loss: 37.0068 - val_mae: 4.6056 - val_rmse: 6.0626
# Epoch 47/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 87ms/step - loss: 31.9432 - mae: 4.3241 - rmse: 5.6294 - val_loss: 37.0951 - val_mae: 4.6037 - val_rmse: 6.0698
# Epoch 48/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 91ms/step - loss: 31.0490 - mae: 4.2346 - rmse: 5.5493 - val_loss: 36.9995 - val_mae: 4.6304 - val_rmse: 6.0617
# Epoch 49/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 84ms/step - loss: 31.4246 - mae: 4.3121 - rmse: 5.5829 - val_loss: 37.3120 - val_mae: 4.6699 - val_rmse: 6.0872
# Epoch 50/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 83ms/step - loss: 31.5809 - mae: 4.3028 - rmse: 5.5967 - val_loss: 37.0347 - val_mae: 4.6316 - val_rmse: 6.0644
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 34.7218 - mae: 4.7055 - rmse: 5.8706
# -> MLP-F-3: Dropout Regularization (0.2): Test RMSE=5.8706, Test R2=0.3655

# %% [markdown]
# From the above results, we see a slight increase in performance. The RMSE and R2 are slightly changing. This suggests a better look into fine tuning other relevant hyperparameters as well.

# %% [markdown]
# # Part 4: Results, Visualizations, and Comparison

# %% [markdown]
# ## 4.1 Comparison of Final Results
#
# Below is a final, comprehensive, systematic results table is mandatory for comparison, clearly documenting the model, hyperparameters, and evaluation metrics (RMSE and $R^2$). This facilitates critical discussion in the final report.

# %%
# Combine and format results
df_ml = pd.DataFrame(results_ml)
df_dl = pd.DataFrame(results_dl)

# Ensure R2 is numeric for sorting purposes, then convert back to string
df_ml['R2 Score_temp'] = df_ml['R2 Score'].astype(float)
df_dl['R2 Score_temp'] = df_dl['R2 Score'].astype(float)

# Sort by R2 Score (Best performance first)
df_ml = df_ml.sort_values(by='R2 Score_temp', ascending=False).drop(columns=['R2 Score_temp'])
df_dl = df_dl.sort_values(by='R2 Score_temp', ascending=False).drop(columns=['R2 Score_temp'])

# Combine the top performing experiments
top_ml = df_ml.head(5)
top_dl = df_dl.head(5)

df_final_comparison = pd.concat([top_ml, top_dl]).reset_index(drop=True)

print("### Traditional ML Results (Top 5 Ranked by R2) ###")
print(top_ml.to_markdown(index=False))

print("\n### Deep Learning Results (Top 5 Ranked by R2) ###")
print(top_dl.to_markdown(index=False))
# Out:
# ### Traditional ML Results (Top 5 Ranked by R2) ###
# | Model                       | Experiment                                            | Hyperparameters/Settings                                                                                                                                                                                                                                                                                                                                                                                                                                                  |   RMSE |   R2 Score | Notes                                                                           |
# |:----------------------------|:------------------------------------------------------|:--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|-------:|-----------:|:--------------------------------------------------------------------------------|
# | Gradient Boosting Regressor | RFR-7: Gradient Boosting Regressor for comparison     | {'alpha': 0.9, 'ccp_alpha': 0.0, 'criterion': 'friedman_mse', 'init': None, 'learning_rate': 0.1, 'loss': 'squared_error', 'max_depth': 3, 'max_features': None, 'max_leaf_nodes': None, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'n_estimators': 100, 'n_iter_no_change': None, 'random_state': 42, 'subsample': 1.0, 'tol': 0.0001, 'validation_fraction': 0.1, 'verbose': 0, 'warm_start': False} | 5.4785 |     0.4474 | Comparison model to RFR (GBR, a boosting algorithm).                            |
# | Random Forest               | RFR-5: Grid Search Optimization                       | {'bootstrap': True, 'ccp_alpha': 0.0, 'criterion': 'squared_error', 'max_depth': 20, 'max_features': 1.0, 'max_leaf_nodes': None, 'max_samples': None, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 1, 'min_samples_split': 10, 'min_weight_fraction_leaf': 0.0, 'monotonic_cst': None, 'n_estimators': 500, 'n_jobs': None, 'oob_score': False, 'random_state': 42, 'verbose': 0, 'warm_start': False}                                                              | 5.6417 |     0.414  | Optimal Params: {'max_depth': 20, 'min_samples_split': 10, 'n_estimators': 500} |
# | Random Forest               | RFR-6: Feature Importance Analysis                    | {'bootstrap': True, 'ccp_alpha': 0.0, 'criterion': 'squared_error', 'max_depth': 20, 'max_features': 1.0, 'max_leaf_nodes': None, 'max_samples': None, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 1, 'min_samples_split': 10, 'min_weight_fraction_leaf': 0.0, 'monotonic_cst': None, 'n_estimators': 500, 'n_jobs': None, 'oob_score': False, 'random_state': 42, 'verbose': 0, 'warm_start': False}                                                              | 5.6417 |     0.414  | Top 3 Features: ['num__s11q2_6', 'num__s11q2_3', 'num__s11q2_8']                |
# | Random Forest               | RFR-3: Ensemble Size (max_depth=10, n_estimators=500) | {'bootstrap': True, 'ccp_alpha': 0.0, 'criterion': 'squared_error', 'max_depth': 10, 'max_features': 1.0, 'max_leaf_nodes': None, 'max_samples': None, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'monotonic_cst': None, 'n_estimators': 500, 'n_jobs': -1, 'oob_score': False, 'random_state': 42, 'verbose': 0, 'warm_start': False}                                                                 | 5.6488 |     0.4125 |                                                                                 |
# | Random Forest               | RFR-2: Tree Depth Tuning (max_depth=10)               | {'bootstrap': True, 'ccp_alpha': 0.0, 'criterion': 'squared_error', 'max_depth': 10, 'max_features': 1.0, 'max_leaf_nodes': None, 'max_samples': None, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'monotonic_cst': None, 'n_estimators': 100, 'n_jobs': None, 'oob_score': False, 'random_state': 42, 'verbose': 0, 'warm_start': False}                                                               | 5.6967 |     0.4025 |                                                                                 |
#
# ### Deep Learning Results (Top 5 Ranked by R2) ###
# | Model          | Experiment                                 | Hyperparameters/Settings             |   RMSE |   R2 Score |   Final Val Loss | Notes      |
# |:---------------|:-------------------------------------------|:-------------------------------------|-------:|-----------:|-----------------:|:-----------|
# | Functional_MLP | MLP-F-3: Dropout Regularization (0.2)      | Layers:128, LR:0.0010000000474974513 | 5.8706 |     0.3655 |          37.0347 | Functional |
# | Sequential_MLP | MLP-S-6: Early Stopping                    | Layers:64, LR:0.0010000000474974513  | 5.8776 |     0.364  |          38.7624 | Sequential |
# | Functional_MLP | MLP-F-2: L2 Regularization                 | Layers:128, LR:0.0010000000474974513 | 5.9564 |     0.3468 |          39.1789 | Functional |
# | Functional_MLP | MLP-F-1: Functional API Baseline           | Layers:128, LR:0.0010000000474974513 | 5.9569 |     0.3467 |          37.9345 | Functional |
# | Sequential_MLP | MLP-S-5: Activation Comparison (LeakyReLU) | Layers:64, LR:0.0010000000474974513  | 6.102  |     0.3145 |          38.6982 | Sequential |

# %% [markdown]
# ## 4.3 Performance Visualization Of the Best Model
#
# Next, let's visualize the best performing model.
#
# Visualizing the actual vs. predicted values helps assess model performance, particularly the tendency for models to under- or over-predict the yield rate. This scatter plot directly illustrates the goodness of fit ($R^2$).

# %%
# Select the single best overall model
best_model_name = df_final_comparison.iloc[0]['Model']
best_exp_name = df_final_comparison.iloc[0]['Experiment']

# Re-evaluate the best model for prediction clarity
Y_pred_best = gbr_model.predict(X_test_processed)
r2_best = r2_score(Y_test_array, Y_pred_best)

plt.figure(figsize=(8, 8))
plt.scatter(Y_test_array, Y_pred_best, alpha=0.6, color='darkgreen')
plt.plot([Y_test_array.min(), Y_test_array.max()], [Y_test_array.min(), Y_test_array.max()], 'r--', lw=2, label='Perfect Prediction (y=x)')
plt.title(f'Actual vs. Predicted Yield Rate (Best Model: {best_exp_name})')
plt.xlabel('Actual Egg Yield Rate')
plt.ylabel('Predicted Egg Yield Rate')
plt.text(Y_test_array.min() + 0.5, Y_test_array.max() - 0.5, f'$R^2$ = {r2_best:.4f}', fontsize=12, color='red')
plt.grid(True, alpha=0.3)
plt.show()
